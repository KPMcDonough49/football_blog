# %%
import pandas as pd 
import numpy as np
import requests
import json

# %%
response = requests.get("http://api.sportradar.us/nfl/official/trial/v7/en/games/2021/REG/schedule.json?api_key=n9yn5ys4mt86x3cfj6t6nxb9")

# %%
response
# Out:
# <Response [200]>

# %%
data = json.loads(response.text)

# %%
data
# Out:
# {'id': '06275f0f-08ff-4787-91fc-5c30464ccfd9',
#  'year': 2021,
#  'type': 'REG',
#  'name': 'REG',
#  'weeks': [{'id': '3ca1343b-9e11-438c-9d7a-5f33cb775c3f',
#    'sequence': 1,
#    'title': '1',
#    'games': [{'id': '01d1210a-d34e-4dc7-9c24-bbd25f5fb3ad',
#      'status': 'closed',
#      'scheduled': '2021-09-10T00:20:00+00:00',
#      'attendance': 65566,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299744',
#      'venue': {'id': '6fccc39c-80bc-4c81-83d9-2d5a848c8c09',
#       'name': 'Raymond James Stadium',
#       'city': 'Tampa',
#       'state': 'FL',
#       'country': 'USA',
#       'zip': '33607',
#       'address': '4201 North Dale Mabry Highway',
#       'capacity': 65890,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8205',
#       'location': {'lat': '27.976211', 'lng': '-82.503625'}},
#      'home': {'id': '4254d319-1bc7-4f81-b4ab-b5e6f3402b69',
#       'name': 'Tampa Bay Buccaneers',
#       'alias': 'TB',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4388'},
#      'away': {'id': 'e627eec7-bbae-4fa4-8e73-8e1d6bc5c060',
#       'name': 'Dallas Cowboys',
#       'alias': 'DAL',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4392'},
#      'broadcast': {'network': 'NBC'},
#      'weather': {'condition': 'Partly cloudy',
#       'humidity': 85,
#       'temp': 82,
#       'wind': {'speed': 9, 'direction': 'WSW'}},
#      'scoring': {'home_points': 31,
#       'away_points': 29,
#       'periods': [{'period_type': 'quarter',
#         'id': '4f82eb0e-21dc-4153-aaf3-0e02530322da',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'dbfd0034-6a25-41e2-a740-a0774342985c',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 14,
#         'away_points': 9},
#        {'period_type': 'quarter',
#         'id': 'a3aa9f44-287e-4161-971f-9ce598c416b2',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '689c4991-d979-4960-bd3b-1c400ddb4ff6',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 3,
#         'away_points': 3}]}},
#     {'id': '11635c85-7cc5-429c-a13a-168b8d92f01f',
#      'status': 'closed',
#      'scheduled': '2021-09-12T17:00:00+00:00',
#      'attendance': 67216,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299762',
#      'venue': {'id': '5295c1b7-c85c-49cb-9569-1707c65324e5',
#       'name': 'Nissan Stadium',
#       'city': 'Nashville',
#       'state': 'TN',
#       'country': 'USA',
#       'zip': '37213',
#       'address': 'One Titans Way',
#       'capacity': 69143,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8207',
#       'location': {'lat': '36.166367', 'lng': '-86.771223'}},
#      'home': {'id': 'd26a1ca5-722d-4274-8f97-c92e49c96315',
#       'name': 'Tennessee Titans',
#       'alias': 'TEN',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:367364'},
#      'away': {'id': 'de760528-1dc0-416a-a978-b510d20692ff',
#       'name': 'Arizona Cardinals',
#       'alias': 'ARI',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4412'},
#      'broadcast': {'network': 'CBS'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 55,
#       'temp': 82,
#       'wind': {'speed': 8, 'direction': 'SW'}},
#      'scoring': {'home_points': 13,
#       'away_points': 38,
#       'periods': [{'period_type': 'quarter',
#         'id': '6fd10b65-e0f8-4a3e-b1f8-1419f5763fb1',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '7a715518-03a6-4837-983f-f0f48194f677',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 6,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': 'afc87ebb-3662-4735-8a49-28226f045bc5',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': 'fc9b3351-7cbf-405e-8d41-625f2bb07013',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 0}]}},
#     {'id': '308bce88-f5d4-4fac-ad23-d6a47abde7be',
#      'status': 'closed',
#      'scheduled': '2021-09-12T17:00:00+00:00',
#      'attendance': 68105,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299750',
#      'venue': {'id': '6a72e5ca-33d0-40af-8e6b-b32a4d3d9346',
#       'name': 'NRG Stadium',
#       'city': 'Houston',
#       'state': 'TX',
#       'country': 'USA',
#       'zip': '77054',
#       'address': 'One Reliant Park',
#       'capacity': 72220,
#       'surface': 'artificial',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:2402',
#       'location': {'lat': '29.684735', 'lng': '-95.410725'}},
#      'home': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#       'name': 'Houston Texans',
#       'alias': 'HOU',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4324'},
#      'away': {'id': 'f7ddd7fa-0bae-4f90-bc8e-669e4d6cf2de',
#       'name': 'Jacksonville Jaguars',
#       'alias': 'JAC',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4386'},
#      'broadcast': {'network': 'CBS'},
#      'weather': {'condition': 'Partly cloudy',
#       'humidity': 58,
#       'temp': 84,
#       'wind': {'speed': 4, 'direction': 'N'}},
#      'scoring': {'home_points': 37,
#       'away_points': 21,
#       'periods': [{'period_type': 'quarter',
#         'id': '9e5d1c6d-80fd-4259-b28e-a2f0a0baabb4',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 14,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'a7862650-436d-44be-a02d-81f92b16c7e4',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 13,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'cd7f87d8-ba1e-43b9-ba82-a6c77ba30a96',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'd0dcfdc8-200d-44c6-b2a1-8c5d4ef5f3b3',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 3,
#         'away_points': 7}]}},
#     {'id': '41145b5f-b1b9-4e9e-95bb-c3292aa791c3',
#      'status': 'closed',
#      'scheduled': '2021-09-12T17:00:00+00:00',
#      'attendance': 56525,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299766',
#      'venue': {'id': 'b87a1595-d3c8-48ea-8a53-0aab6378a64a',
#       'name': 'Paul Brown Stadium',
#       'city': 'Cincinnati',
#       'state': 'OH',
#       'country': 'USA',
#       'zip': '45202',
#       'address': 'One Paul Brown Stadium',
#       'capacity': 65515,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8175',
#       'location': {'lat': '39.095413', 'lng': '-84.516204'}},
#      'home': {'id': 'ad4ae08f-d808-42d5-a1e6-e9bc4e34d123',
#       'name': 'Cincinnati Bengals',
#       'alias': 'CIN',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4416'},
#      'away': {'id': '33405046-04ee-4058-a950-d606f8c30852',
#       'name': 'Minnesota Vikings',
#       'alias': 'MIN',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4423'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 54,
#       'temp': 81,
#       'wind': {'speed': 15, 'direction': 'SSW'}},
#      'scoring': {'home_points': 27,
#       'away_points': 24,
#       'periods': [{'period_type': 'quarter',
#         'id': 'bb008516-8b0a-44a0-870f-fe1762183618',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '72327703-a1b1-4cfa-a0f2-ee16f68b8828',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 14,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'e405ec90-be3d-4557-b13a-9c1f038464b8',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '6b1e221c-9ef4-465e-b365-78693f7d8ad4',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 3,
#         'away_points': 10},
#        {'period_type': 'overtime',
#         'id': '9e82ec0b-9e32-4d59-99ce-5b839f414b3d',
#         'number': 1,
#         'sequence': 5,
#         'home_points': 3,
#         'away_points': 0}]}},
#     {'id': '616216d2-6e3f-41dd-9a47-1b7ce1e6b0d7',
#      'status': 'closed',
#      'scheduled': '2021-09-12T17:00:00+00:00',
#      'attendance': 63347,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299772',
#      'venue': {'id': '6ed18563-53e0-46c2-a91d-12d73a16456d',
#       'name': 'Lucas Oil Stadium',
#       'city': 'Indianapolis',
#       'state': 'IN',
#       'country': 'USA',
#       'zip': '46225',
#       'address': '500 South Capitol Avenue',
#       'capacity': 67000,
#       'surface': 'artificial',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:8185',
#       'location': {'lat': '39.760008', 'lng': '-86.163906'}},
#      'home': {'id': '82cf9565-6eb9-4f01-bdbd-5aa0d472fcd9',
#       'name': 'Indianapolis Colts',
#       'alias': 'IND',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4421'},
#      'away': {'id': '3d08af9e-c767-4f88-a7dc-b920c6d2b4a8',
#       'name': 'Seattle Seahawks',
#       'alias': 'SEA',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4430'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Partly cloudy',
#       'humidity': 51,
#       'temp': 81,
#       'wind': {'speed': 19, 'direction': 'SW'}},
#      'scoring': {'home_points': 16,
#       'away_points': 28,
#       'periods': [{'period_type': 'quarter',
#         'id': 'b92ab6a8-d7b6-40cb-9078-a8b7400e62d0',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '531da782-75c7-4664-adba-8796170ef2ae',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': 'e8575957-94be-42ac-bc21-255a8a6d1581',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'cdf4379e-ab2c-4e1a-872e-ff3374046805',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 6,
#         'away_points': 7}]}},
#     {'id': '63cca58f-b316-4c57-9cea-fc056c665c6c',
#      'status': 'closed',
#      'scheduled': '2021-09-12T17:00:00+00:00',
#      'attendance': 69787,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299754',
#      'venue': {'id': 'e9e0828e-37fc-4238-a317-49037577dd55',
#       'name': 'Highmark Stadium',
#       'city': 'Orchard Park',
#       'state': 'NY',
#       'country': 'USA',
#       'zip': '14127',
#       'address': 'One Bills Drive',
#       'capacity': 71608,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8171',
#       'location': {'lat': '42.773826', 'lng': '-78.786589'}},
#      'home': {'id': '768c92aa-75ff-4a43-bcc0-f2798c2e1724',
#       'name': 'Buffalo Bills',
#       'alias': 'BUF',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4376'},
#      'away': {'id': 'cb2f9f1f-ac67-424e-9e72-1475cb0ed398',
#       'name': 'Pittsburgh Steelers',
#       'alias': 'PIT',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4345'},
#      'broadcast': {'network': 'CBS'},
#      'weather': {'condition': 'Overcast',
#       'humidity': 79,
#       'temp': 73,
#       'wind': {'speed': 17, 'direction': 'WSW'}},
#      'scoring': {'home_points': 16,
#       'away_points': 23,
#       'periods': [{'period_type': 'quarter',
#         'id': '56e20382-bcce-4030-9450-9d03304171cf',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'd40362fe-eac7-452c-a927-d981912bc250',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'c3192fc8-f1d9-4a78-b860-8c896e19d44f',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 6},
#        {'period_type': 'quarter',
#         'id': '7a575829-2ae9-430c-b208-beeafb3aa9c1',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 6,
#         'away_points': 17}]}},
#     {'id': '90d6aa77-e522-4c20-970c-01a61bc04e36',
#      'status': 'closed',
#      'scheduled': '2021-09-12T17:00:00+00:00',
#      'attendance': 59374,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299768',
#      'venue': {'id': '6e3bcf22-277d-4c06-b019-62aded51654f',
#       'name': 'Ford Field',
#       'city': 'Detroit',
#       'state': 'MI',
#       'country': 'USA',
#       'zip': '48226',
#       'address': '2000 Brush Street',
#       'capacity': 65000,
#       'surface': 'artificial',
#       'roof_type': 'dome',
#       'sr_id': 'sr:venue:8181',
#       'location': {'lat': '42.339958', 'lng': '-83.045636'}},
#      'home': {'id': 'c5a59daa-53a7-4de0-851f-fb12be893e9e',
#       'name': 'Detroit Lions',
#       'alias': 'DET',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4419'},
#      'away': {'id': 'f0e724b0-4cbf-495a-be47-013907608da9',
#       'name': 'San Francisco 49ers',
#       'alias': 'SF',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4389'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Partly cloudy',
#       'humidity': 65,
#       'temp': 79,
#       'wind': {'speed': 8, 'direction': 'W'}},
#      'scoring': {'home_points': 33,
#       'away_points': 41,
#       'periods': [{'period_type': 'quarter',
#         'id': 'acb71ad3-a484-4210-b8c2-da8d9f12dbbb',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'ebb73243-96e6-40bd-8d8e-af9ffc00f17c',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 10,
#         'away_points': 24},
#        {'period_type': 'quarter',
#         'id': '2fbaa5a3-ec4b-4a32-8308-c207eb30ec5e',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '208f3ee6-bd79-40e8-89f5-c641f73f87a5',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 16,
#         'away_points': 3}]}},
#     {'id': 'a60b9775-cc49-4a09-9382-31fd6efdf4e7',
#      'status': 'closed',
#      'scheduled': '2021-09-12T17:00:00+00:00',
#      'attendance': 52753,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299764',
#      'venue': {'id': '7c11bb2d-4a53-4842-b842-0f1c63ed78e9',
#       'name': 'FedExField',
#       'city': 'Landover',
#       'state': 'MD',
#       'country': 'USA',
#       'zip': '20785',
#       'address': '1600 FedEx Way',
#       'capacity': 82000,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:6652',
#       'location': {'lat': '38.907724', 'lng': '-76.864613'}},
#      'home': {'id': '22052ff7-c065-42ee-bc8f-c4691c50e624',
#       'name': 'Washington Football Team',
#       'alias': 'WAS',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4432'},
#      'away': {'id': '1f6dcffb-9823-43cd-9ff4-e7a8466749b5',
#       'name': 'Los Angeles Chargers',
#       'alias': 'LAC',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4429'},
#      'broadcast': {'network': 'CBS'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 49,
#       'temp': 81,
#       'wind': {'speed': 4, 'direction': 'S'}},
#      'scoring': {'home_points': 16,
#       'away_points': 20,
#       'periods': [{'period_type': 'quarter',
#         'id': '577f470a-db07-47d2-8976-eb4e2b6e01b4',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'f33a1c03-f5c0-49f6-afc7-9869d347c234',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 6,
#         'away_points': 6},
#        {'period_type': 'quarter',
#         'id': '7a0200c4-2361-4f8c-8d61-306da6a53d1e',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '0a4294f6-9235-4dbd-9249-dd8e1342f029',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 7}]}},
#     {'id': 'a74cb1bc-23a4-482e-a389-a622fa05faff',
#      'status': 'closed',
#      'scheduled': '2021-09-12T17:00:00+00:00',
#      'attendance': 70211,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299760',
#      'venue': {'id': '39be9ed4-3292-49ac-8699-a381de3a4969',
#       'name': 'Bank of America Stadium',
#       'city': 'Charlotte',
#       'state': 'NC',
#       'country': 'USA',
#       'zip': '28202',
#       'address': '800 South Mint Street',
#       'capacity': 75419,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8173',
#       'location': {'lat': '35.225937', 'lng': '-80.853133'}},
#      'home': {'id': 'f14bf5cc-9a82-4a38-bc15-d39f75ed5314',
#       'name': 'Carolina Panthers',
#       'alias': 'CAR',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4415'},
#      'away': {'id': '5fee86ae-74ab-4bdd-8416-42a9dd9964f3',
#       'name': 'New York Jets',
#       'alias': 'NYJ',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4427'},
#      'broadcast': {'network': 'CBS'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 51,
#       'temp': 81,
#       'wind': {'speed': 0, 'direction': 'WSW'}},
#      'scoring': {'home_points': 19,
#       'away_points': 14,
#       'periods': [{'period_type': 'quarter',
#         'id': '85a7b208-ac3b-4332-ad61-dbf46fa10176',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '25cd6e15-e731-4498-9dc8-79673f934af5',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 16,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '4d7b7635-17a1-4c15-b857-28c9a044e3bd',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 8},
#        {'period_type': 'quarter',
#         'id': '91eb8923-38ea-49ef-8d13-5c6c766f4fb8',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 3,
#         'away_points': 6}]}},
#     {'id': 'fb4085e6-3290-49d1-84e4-e254f817cd7f',
#      'status': 'closed',
#      'scheduled': '2021-09-12T17:00:00+00:00',
#      'attendance': 68633,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299770',
#      'venue': {'id': '1f2d393b-2291-4835-a412-0714966ea245',
#       'name': 'Mercedes-Benz Stadium',
#       'city': 'Atlanta',
#       'state': 'GA',
#       'country': 'USA',
#       'zip': '30313',
#       'address': '441 Martin Luther King Jr Drive NW',
#       'capacity': 71000,
#       'surface': 'artificial',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:20343',
#       'location': {'lat': '33.757368', 'lng': '-84.401008'}},
#      'home': {'id': 'e6aa13a4-0055-48a9-bc41-be28dc106929',
#       'name': 'Atlanta Falcons',
#       'alias': 'ATL',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4393'},
#      'away': {'id': '386bdbf9-9eea-4869-bb9a-274b0bc66e80',
#       'name': 'Philadelphia Eagles',
#       'alias': 'PHI',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4428'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 72,
#       'temp': 79,
#       'wind': {'speed': 0, 'direction': 'E'}},
#      'scoring': {'home_points': 6,
#       'away_points': 32,
#       'periods': [{'period_type': 'quarter',
#         'id': '716c0a22-c6f0-4adf-99a6-47a424fa567e',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'd5670255-31dc-4097-b58e-7ca63907e828',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 3,
#         'away_points': 8},
#        {'period_type': 'quarter',
#         'id': 'ebb2f943-1166-4849-97b1-19b9c3617a34',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'f5f37e69-b2ce-456d-af45-49b506f2901d',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 10}]}},
#     {'id': '22a36a47-e07c-42d9-b5d8-ee1709b68a14',
#      'status': 'closed',
#      'scheduled': '2021-09-12T20:25:00+00:00',
#      'attendance': 72973,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299774',
#      'venue': {'id': '2ec4c411-dac2-403d-b091-6b6aa4a0a914',
#       'name': 'GEHA Field at Arrowhead Stadium',
#       'city': 'Kansas City',
#       'state': 'MO',
#       'country': 'USA',
#       'zip': '64129',
#       'address': 'One Arrowhead Drive',
#       'capacity': 76416,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8189',
#       'location': {'lat': '39.049019', 'lng': '-94.484140'}},
#      'home': {'id': '6680d28d-d4d2-49f6-aace-5292d3ec02c2',
#       'name': 'Kansas City Chiefs',
#       'alias': 'KC',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4422'},
#      'away': {'id': 'd5a2eb42-8065-4174-ab79-0a6fa820e35e',
#       'name': 'Cleveland Browns',
#       'alias': 'CLE',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4417'},
#      'broadcast': {'network': 'CBS'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 43,
#       'temp': 88,
#       'wind': {'speed': 8, 'direction': 'S'}},
#      'scoring': {'home_points': 33,
#       'away_points': 29,
#       'periods': [{'period_type': 'quarter',
#         'id': '995950b6-b800-41a2-a46c-e50396e0de26',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 8},
#        {'period_type': 'quarter',
#         'id': '119132c5-d4bc-4919-aa66-9d06f5a2ec24',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': 'f88cfce1-5fb8-4a42-921e-efc2c1993c9c',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 10,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '94c9e554-808b-43d2-98b3-a6a8fded48dd',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 13,
#         'away_points': 7}]}},
#     {'id': '633711b1-a6c4-46c1-99f2-3279c744ff58',
#      'status': 'closed',
#      'scheduled': '2021-09-12T20:25:00+00:00',
#      'attendance': 35242,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299780',
#      'venue': {'id': '4c5c036d-dd3d-4183-b595-71a43a97560f',
#       'name': 'TIAA Bank Field',
#       'city': 'Jacksonville',
#       'state': 'FL',
#       'country': 'USA',
#       'zip': '32202',
#       'address': 'One EverBank Field Drive',
#       'capacity': 69132,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8187',
#       'location': {'lat': '30.324027', 'lng': '-81.637239'}},
#      'home': {'id': '0d855753-ea21-4953-89f9-0e20aff9eb73',
#       'name': 'New Orleans Saints',
#       'alias': 'NO',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4425'},
#      'away': {'id': 'a20471b4-a8d9-40c7-95ad-90cc30e46932',
#       'name': 'Green Bay Packers',
#       'alias': 'GB',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4420'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Partly cloudy',
#       'humidity': 57,
#       'temp': 86,
#       'wind': {'speed': 9, 'direction': 'ENE'}},
#      'scoring': {'home_points': 38,
#       'away_points': 3,
#       'periods': [{'period_type': 'quarter',
#         'id': 'a85a769c-cd99-4d33-a191-1711328e6766',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '9d9f2e0a-dd5b-4f3b-a2cd-33f6d2066528',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 14,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '9c8dfb5c-1a04-4b92-9286-3e61ad7a5355',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '9d9b9a4a-5979-4aaf-a6b0-3680c3e79577',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 14,
#         'away_points': 0}]}},
#     {'id': '8c17016f-1c58-4976-a6bd-0ab920a97315',
#      'status': 'closed',
#      'scheduled': '2021-09-12T20:25:00+00:00',
#      'attendance': 74119,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299778',
#      'venue': {'id': '5d4c85c7-d84e-4e10-bd6a-8a15ebecca5c',
#       'name': 'MetLife Stadium',
#       'city': 'East Rutherford',
#       'state': 'NJ',
#       'country': 'USA',
#       'zip': '07073',
#       'address': 'One MetLife Stadium Drive',
#       'capacity': 82500,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:1981',
#       'location': {'lat': '40.813611', 'lng': '-74.074444'}},
#      'home': {'id': '04aa1c9d-66da-489d-b16a-1dee3f2eec4d',
#       'name': 'New York Giants',
#       'alias': 'NYG',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4426'},
#      'away': {'id': 'ce92bd47-93d5-4fe9-ada4-0fc681e6caa0',
#       'name': 'Denver Broncos',
#       'alias': 'DEN',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4418'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 56,
#       'temp': 82,
#       'wind': {'speed': 19, 'direction': 'SW'}},
#      'scoring': {'home_points': 13,
#       'away_points': 27,
#       'periods': [{'period_type': 'quarter',
#         'id': 'bb5e46e7-026b-4a94-952e-5e14c79b5a29',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '94f91d05-56b5-4539-9d05-5d40408ad6f7',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '19998741-7f4d-480e-9271-f815206e7276',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '8ac49efc-16fa-4909-bc81-a3db097fa6b2',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 6,
#         'away_points': 10}]}},
#     {'id': 'd2228d80-4cbf-46a2-8a2d-12fc2ef2935a',
#      'status': 'closed',
#      'scheduled': '2021-09-12T20:25:00+00:00',
#      'attendance': 65878,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299776',
#      'venue': {'id': 'e43310b1-cb82-4df9-8be5-e9b39637031b',
#       'name': 'Gillette Stadium',
#       'city': 'Foxborough',
#       'state': 'MA',
#       'country': 'USA',
#       'zip': '02035',
#       'address': 'One Patriot Place',
#       'capacity': 66829,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:2379',
#       'location': {'lat': '42.090944', 'lng': '-71.264344'}},
#      'home': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#       'name': 'New England Patriots',
#       'alias': 'NE',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4424'},
#      'away': {'id': '4809ecb0-abd3-451d-9c4a-92a90b83ca06',
#       'name': 'Miami Dolphins',
#       'alias': 'MIA',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4287'},
#      'broadcast': {'network': 'CBS'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 58,
#       'temp': 81,
#       'wind': {'speed': 15, 'direction': 'SSW'}},
#      'scoring': {'home_points': 16,
#       'away_points': 17,
#       'periods': [{'period_type': 'quarter',
#         'id': '55f430b7-d9ff-4656-9906-23c19df1f301',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'd7d6f07b-d37c-45d1-9d32-9cd5381757e1',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 10,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '55bd246b-9913-4021-8c88-26608d0e7cc9',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 3,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '5a40d631-1e73-49d7-babb-e8bef23b9008',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 3,
#         'away_points': 0}]}},
#     {'id': 'c9d06837-0ac3-4d3f-8d7f-eae447b531fa',
#      'status': 'closed',
#      'scheduled': '2021-09-13T00:20:00+00:00',
#      'attendance': 70445,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299782',
#      'venue': {'id': '790c1f04-73c6-4f6f-8b1e-78a62260be90',
#       'name': 'SoFi Stadium',
#       'city': 'Inglewood',
#       'state': 'CA',
#       'country': 'USA',
#       'zip': '90301',
#       'address': '1000 S Prairie Ave',
#       'capacity': 70240,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:52183',
#       'location': {'lat': '33.953536', 'lng': '-118.338734'}},
#      'home': {'id': '2eff2a03-54d4-46ba-890e-2bc3925548f3',
#       'name': 'Los Angeles Rams',
#       'alias': 'LA',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4387'},
#      'away': {'id': '7b112545-38e6-483c-a55c-96cf6ee49cb8',
#       'name': 'Chicago Bears',
#       'alias': 'CHI',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4391'},
#      'broadcast': {'network': 'NBC'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 61,
#       'temp': 72,
#       'wind': {'speed': 12, 'direction': 'W'}},
#      'scoring': {'home_points': 34,
#       'away_points': 14,
#       'periods': [{'period_type': 'quarter',
#         'id': 'e9199bf5-7f1c-4593-82e1-2fa4e24db8ee',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 10,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '49a59e28-0257-4de4-b30a-fff93889e574',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 3,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'f6df02b4-212f-4f25-a9a4-467755dad6c2',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 14,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'bdd8bf08-bc19-4da6-b1b9-41634f53abdc',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 7,
#         'away_points': 0}]}},
#     {'id': '6ec6abfa-46ed-4011-8068-5c1fea90a0ee',
#      'status': 'closed',
#      'scheduled': '2021-09-14T00:15:00+00:00',
#      'attendance': 61756,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27299784',
#      'venue': {'id': '53d42601-5dfb-40a7-bd94-da2c1d3a75e4',
#       'name': 'Allegiant Stadium',
#       'city': 'Las Vegas',
#       'state': 'NV',
#       'country': 'USA',
#       'zip': '89118',
#       'address': '3333 Al Davis Way',
#       'capacity': 65000,
#       'surface': 'turf',
#       'roof_type': 'dome',
#       'sr_id': 'sr:venue:51543',
#       'location': {'lat': '36.090852', 'lng': '-115.183339'}},
#      'home': {'id': '7d4fcc64-9cb5-4d1b-8e75-8a906d1e1576',
#       'name': 'Las Vegas Raiders',
#       'alias': 'LV',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4390'},
#      'away': {'id': 'ebd87119-b331-4469-9ea6-d51fe3ce2f1c',
#       'name': 'Baltimore Ravens',
#       'alias': 'BAL',
#       'game_number': 1,
#       'sr_id': 'sr:competitor:4413'},
#      'broadcast': {'network': 'ESPN', 'satellite': '206'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 8,
#       'temp': 102,
#       'wind': {'speed': 16, 'direction': 'SW'}},
#      'scoring': {'home_points': 33,
#       'away_points': 27,
#       'periods': [{'period_type': 'quarter',
#         'id': '092f3096-1a7e-44d8-b857-c415c652d96f',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '17a9d604-a492-41f0-8700-25677369882b',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 10,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '80f95556-6c66-4124-b092-8bd9c83eff3e',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '65c60887-d711-4c17-a313-3f66213f273a',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 17,
#         'away_points': 10},
#        {'period_type': 'overtime',
#         'id': 'db516945-a555-4097-90b7-d52fdcd92ff8',
#         'number': 1,
#         'sequence': 5,
#         'home_points': 6,
#         'away_points': 0}]}}]},
#   {'id': '12ca3bfb-6503-4dda-9c0d-4697993a7f6d',
#    'sequence': 2,
#    'title': '2',
#    'games': [{'id': '765bd39d-e8c2-4bc3-9a5d-4d8ece62e953',
#      'status': 'closed',
#      'scheduled': '2021-09-17T00:20:00+00:00',
#      'attendance': 50118,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27305798',
#      'venue': {'id': '7c11bb2d-4a53-4842-b842-0f1c63ed78e9',
#       'name': 'FedExField',
#       'city': 'Landover',
#       'state': 'MD',
#       'country': 'USA',
#       'zip': '20785',
#       'address': '1600 FedEx Way',
#       'capacity': 82000,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:6652',
#       'location': {'lat': '38.907724', 'lng': '-76.864613'}},
#      'home': {'id': '22052ff7-c065-42ee-bc8f-c4691c50e624',
#       'name': 'Washington Football Team',
#       'alias': 'WAS',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4432'},
#      'away': {'id': '04aa1c9d-66da-489d-b16a-1dee3f2eec4d',
#       'name': 'New York Giants',
#       'alias': 'NYG',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4426'},
#      'broadcast': {'network': 'NFL Network', 'satellite': '212'},
#      'weather': {'condition': 'Overcast',
#       'humidity': 94,
#       'temp': 71,
#       'wind': {'speed': 0, 'direction': 'N'}},
#      'scoring': {'home_points': 30,
#       'away_points': 29,
#       'periods': [{'period_type': 'quarter',
#         'id': 'f6cd45ef-4992-407c-a7b5-3b204f0bfe8b',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '32e2c86d-eb89-49e3-b234-9bf3dc8bf3fa',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 14,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '817ae3cf-a4e2-47c5-b8bf-82dd4b0b2747',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 3,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': '7df08fd3-d339-412c-87dc-4a594b549d77',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 13,
#         'away_points': 9}]}},
#     {'id': '0134fb02-2a84-4176-8ed8-d3b8db9ba570',
#      'status': 'closed',
#      'scheduled': '2021-09-19T17:00:00+00:00',
#      'attendance': 58461,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27305802',
#      'venue': {'id': '4c5c036d-dd3d-4183-b595-71a43a97560f',
#       'name': 'TIAA Bank Field',
#       'city': 'Jacksonville',
#       'state': 'FL',
#       'country': 'USA',
#       'zip': '32202',
#       'address': 'One EverBank Field Drive',
#       'capacity': 69132,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8187',
#       'location': {'lat': '30.324027', 'lng': '-81.637239'}},
#      'home': {'id': 'f7ddd7fa-0bae-4f90-bc8e-669e4d6cf2de',
#       'name': 'Jacksonville Jaguars',
#       'alias': 'JAC',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4386'},
#      'away': {'id': 'ce92bd47-93d5-4fe9-ada4-0fc681e6caa0',
#       'name': 'Denver Broncos',
#       'alias': 'DEN',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4418'},
#      'broadcast': {'network': 'CBS'},
#      'weather': {'condition': 'Partly cloudy',
#       'humidity': 87,
#       'temp': 80,
#       'wind': {'speed': 7, 'direction': 'ENE'}},
#      'scoring': {'home_points': 13,
#       'away_points': 23,
#       'periods': [{'period_type': 'quarter',
#         'id': 'f02e2252-e231-411c-afbf-a77feaa96b37',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '7021aaaa-d5a6-412b-ae5d-a9f4b99499bd',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '01d83a45-6162-46a4-82bf-128296e5aae1',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 10},
#        {'period_type': 'quarter',
#         'id': 'fa9ec654-bff9-423c-b607-ebfee9bba9de',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 6,
#         'away_points': 3}]}},
#     {'id': '17283cbb-1ee1-4959-939b-a37df44c3497',
#      'status': 'closed',
#      'scheduled': '2021-09-19T17:00:00+00:00',
#      'attendance': 65040,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27305804',
#      'venue': {'id': '50a5c833-1570-4c38-abc7-7914cf87dbde',
#       'name': 'Hard Rock Stadium',
#       'city': 'Miami Gardens',
#       'state': 'FL',
#       'country': 'USA',
#       'zip': '33056',
#       'address': '2269 Northwest 199th Street',
#       'capacity': 65326,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:21306',
#       'location': {'lat': '25.958025', 'lng': '-80.238724'}},
#      'home': {'id': '4809ecb0-abd3-451d-9c4a-92a90b83ca06',
#       'name': 'Miami Dolphins',
#       'alias': 'MIA',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4287'},
#      'away': {'id': '768c92aa-75ff-4a43-bcc0-f2798c2e1724',
#       'name': 'Buffalo Bills',
#       'alias': 'BUF',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4376'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Partly cloudy',
#       'humidity': 59,
#       'temp': 89,
#       'wind': {'speed': 7, 'direction': 'NNE'}},
#      'scoring': {'home_points': 0,
#       'away_points': 35,
#       'periods': [{'period_type': 'quarter',
#         'id': 'aa9f1f1f-2a59-4d0a-ad46-8509891547dc',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 14},
#        {'period_type': 'quarter',
#         'id': '442c10e2-5388-45d9-bf3a-e8703322e6ff',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'b16b3c28-b075-4bbe-b9f4-79e817d8fb16',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '6a9a2c00-49e8-47df-87b9-890b5036604c',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 0,
#         'away_points': 14}]}},
#     {'id': '2c53a716-59e4-483c-9d9b-3f9d60f410a3',
#      'status': 'closed',
#      'scheduled': '2021-09-19T17:00:00+00:00',
#      'attendance': 67431,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27305814',
#      'venue': {'id': '90c38d91-3774-4f5d-82ca-1c806828219f',
#       'name': 'FirstEnergy Stadium',
#       'city': 'Cleveland',
#       'state': 'OH',
#       'country': 'USA',
#       'zip': '44114',
#       'address': '100 Alfred Lerner Way',
#       'capacity': 67895,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8177',
#       'location': {'lat': '41.506054', 'lng': '-81.700004'}},
#      'home': {'id': 'd5a2eb42-8065-4174-ab79-0a6fa820e35e',
#       'name': 'Cleveland Browns',
#       'alias': 'CLE',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4417'},
#      'away': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#       'name': 'Houston Texans',
#       'alias': 'HOU',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4324'},
#      'broadcast': {'network': 'CBS'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 66,
#       'temp': 75,
#       'wind': {'speed': 12, 'direction': 'NNE'}},
#      'scoring': {'home_points': 31,
#       'away_points': 21,
#       'periods': [{'period_type': 'quarter',
#         'id': '55d105dc-b127-41f7-8b4b-51644eab6fab',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '29aef730-3075-4d64-b2c9-1ca9b75a8da3',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 7,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'fb77660e-a05f-40c7-9ac6-ae2284d953c9',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 10,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '9fd47ced-5f73-4ff8-a26d-e2a30739a7ed',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 7,
#         'away_points': 7}]}},
#     {'id': '60f29b9d-74c4-4a02-8c6a-8fbb88d602cc',
#      'status': 'closed',
#      'scheduled': '2021-09-19T17:00:00+00:00',
#      'attendance': 60840,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27305812',
#      'venue': {'id': 'd7866605-5ac6-4b3a-90e8-760cc5a26b75',
#       'name': 'Soldier Field',
#       'city': 'Chicago',
#       'state': 'IL',
#       'country': 'USA',
#       'zip': '60605',
#       'address': '1410 South Museum Campus Drive',
#       'capacity': 61500,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:2109',
#       'location': {'lat': '41.862498', 'lng': '-87.616979'}},
#      'home': {'id': '7b112545-38e6-483c-a55c-96cf6ee49cb8',
#       'name': 'Chicago Bears',
#       'alias': 'CHI',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4391'},
#      'away': {'id': 'ad4ae08f-d808-42d5-a1e6-e9bc4e34d123',
#       'name': 'Cincinnati Bengals',
#       'alias': 'CIN',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4416'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Sunny',
#       'humidity': 52,
#       'temp': 80,
#       'wind': {'speed': 0, 'direction': 'N'}},
#      'scoring': {'home_points': 20,
#       'away_points': 17,
#       'periods': [{'period_type': 'quarter',
#         'id': 'c5514fa4-15fd-4f52-9d60-5ded742cc734',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '4e9a7849-4783-46ab-a1fd-ec6b21022135',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'e4ecf0d7-8627-47dc-8015-1b2d66c8575c',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': '6f264a10-5a0d-491a-9c49-f4c883193b7b',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 13,
#         'away_points': 14}]}},
#     {'id': '77511f3c-77d2-4940-80ea-7aba4e6d8715',
#      'status': 'closed',
#      'scheduled': '2021-09-19T17:00:00+00:00',
#      'attendance': 69796,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27305806',
#      'venue': {'id': '4fa8c29c-6626-464c-8540-314ed7535e1b',
#       'name': 'Lincoln Financial Field',
#       'city': 'Philadelphia',
#       'state': 'PA',
#       'country': 'USA',
#       'zip': '19148',
#       'address': '1020 Pattison Avenue',
#       'capacity': 69596,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:1833',
#       'location': {'lat': '39.900872', 'lng': '-75.167311'}},
#      'home': {'id': '386bdbf9-9eea-4869-bb9a-274b0bc66e80',
#       'name': 'Philadelphia Eagles',
#       'alias': 'PHI',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4428'},
#      'away': {'id': 'f0e724b0-4cbf-495a-be47-013907608da9',
#       'name': 'San Francisco 49ers',
#       'alias': 'SF',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4389'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Partly cloudy',
#       'humidity': 42,
#       'temp': 76,
#       'wind': {'speed': 13, 'direction': 'N'}},
#      'scoring': {'home_points': 11,
#       'away_points': 17,
#       'periods': [{'period_type': 'quarter',
#         'id': 'f4944ab7-8fe3-4e16-b008-7f00b84c9d19',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 3,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '7c0466ac-82a2-4643-9e40-0e4e10992f84',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'af29352c-d8b7-45ae-a934-6f29f60076d3',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '2fc8d3e4-22cb-4b4b-bd9e-d44cd80806b5',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 8,
#         'away_points': 10}]}},
#     {'id': '9854e2d9-839f-4a09-9ae7-2b233f0cff47',
#      'status': 'closed',
#      'scheduled': '2021-09-19T17:00:00+00:00',
#      'attendance': 70675,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27305816',
#      'venue': {'id': '39be9ed4-3292-49ac-8699-a381de3a4969',
#       'name': 'Bank of America Stadium',
#       'city': 'Charlotte',
#       'state': 'NC',
#       'country': 'USA',
#       'zip': '28202',
#       'address': '800 South Mint Street',
#       'capacity': 75419,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8173',
#       'location': {'lat': '35.225937', 'lng': '-80.853133'}},
#      'home': {'id': 'f14bf5cc-9a82-4a38-bc15-d39f75ed5314',
#       'name': 'Carolina Panthers',
#       'alias': 'CAR',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4415'},
#      'away': {'id': '0d855753-ea21-4953-89f9-0e20aff9eb73',
#       'name': 'New Orleans Saints',
#       'alias': 'NO',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4425'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Partly cloudy',
#       'humidity': 65,
#       'temp': 83,
#       'wind': {'speed': 4, 'direction': 'ENE'}},
#      'scoring': {'home_points': 26,
#       'away_points': 7,
#       'periods': [{'period_type': 'quarter',
#         'id': '36b3e0d9-7e28-4d32-b851-0dcb44bb02cf',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 7,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'd282e119-c282-4a02-9267-020d9785ccef',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 10,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': '63fa5d12-e5e5-4faa-8ec1-3b56691fbaf9',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 0,
#         'away_points': 0},
#        {'period_type': 'quarter',
#         'id': 'f433a6d0-73b5-497f-bcb6-15901fef58f2',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 9,
#         'away_points': 7}]}},
#     {'id': 'b9d24a70-ab6b-4571-ab77-2f78a80287b4',
#      'status': 'closed',
#      'scheduled': '2021-09-19T17:00:00+00:00',
#      'attendance': 63076,
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27305808',
#      'venue': {'id': '6ed18563-53e0-46c2-a91d-12d73a16456d',
#       'name': 'Lucas Oil Stadium',
#       'city': 'Indianapolis',
#       'state': 'IN',
#       'country': 'USA',
#       'zip': '46225',
#       'address': '500 South Capitol Avenue',
#       'capacity': 67000,
#       'surface': 'artificial',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:8185',
#       'location': {'lat': '39.760008', 'lng': '-86.163906'}},
#      'home': {'id': '82cf9565-6eb9-4f01-bdbd-5aa0d472fcd9',
#       'name': 'Indianapolis Colts',
#       'alias': 'IND',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4421'},
#      'away': {'id': '2eff2a03-54d4-46ba-890e-2bc3925548f3',
#       'name': 'Los Angeles Rams',
#       'alias': 'LA',
#       'game_number': 2,
#       'sr_id': 'sr:competitor:4387'},
#      'broadcast': {'network': 'FOX'},
#      'weather': {'condition': 'Partly cloudy',
#       'humidity': 65,
#       'temp': 81,
#       'wind': {'speed': 8, 'direction': 'SSE'}},
#      'scoring': {'home_points': 24,
#       'away_points': 27,
#       'periods': [{'period_type': 'quarter',
#         'id': '453513fa-a11c-43b5-907c-bb9e7604a425',
#         'number': 1,
#         'sequence': 1,
#         'home_points': 0,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': 'fdab2ff4-c57c-47af-8fd4-3286d197d52f',
#         'number': 2,
#         'sequence': 2,
#         'home_points': 6,
#         'away_points': 3},
#        {'period_type': 'quarter',
#         'id': 'bc171b5b-ebdf-4f49-9c74-9a664e5d9567',
#         'number': 3,
#         'sequence': 3,
#         'home_points': 8,
#         'away_points': 7},
#        {'period_type': 'quarter',
#         'id': '9d8a89d6-a5f8-44de-b90d-2c4dc7611efb',
#         'number': 4,
#         'sequence': 4,
#         'home_points': 10,
#         'away_points': 10}]}},
#     {'id': 'ce2f426c-b2fc-4bf0-a238-f028ad6b1a24',
#      'status': 'closed',
#      'scheduled': '2021-09-19T17:00:00+00:00',
#      'attendance': 63707,
# ...
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306292',
#      'venue': {'id': 'd54faae0-0314-484f-8604-9d8dd08e1149',
#       'name': 'M&T Bank Stadium',
#       'city': 'Baltimore',
#       'state': 'MD',
#       'country': 'USA',
#       'zip': '21230',
#       'address': '1101 Russell Street',
#       'capacity': 71008,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8169',
#       'location': {'lat': '39.277995', 'lng': '-76.622592'}},
#      'home': {'id': 'ebd87119-b331-4469-9ea6-d51fe3ce2f1c',
#       'name': 'Baltimore Ravens',
#       'alias': 'BAL',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4413'},
#      'away': {'id': 'cb2f9f1f-ac67-424e-9e72-1475cb0ed398',
#       'name': 'Pittsburgh Steelers',
#       'alias': 'PIT',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4345'},
#      'broadcast': {'network': 'CBS'}},
#     {'id': '1c648ef4-2bb2-4847-ad48-4e317d62fa3c',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306294',
#      'venue': {'id': 'e9e0828e-37fc-4238-a317-49037577dd55',
#       'name': 'Highmark Stadium',
#       'city': 'Orchard Park',
#       'state': 'NY',
#       'country': 'USA',
#       'zip': '14127',
#       'address': 'One Bills Drive',
#       'capacity': 71608,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8171',
#       'location': {'lat': '42.773826', 'lng': '-78.786589'}},
#      'home': {'id': '768c92aa-75ff-4a43-bcc0-f2798c2e1724',
#       'name': 'Buffalo Bills',
#       'alias': 'BUF',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4376'},
#      'away': {'id': '5fee86ae-74ab-4bdd-8416-42a9dd9964f3',
#       'name': 'New York Jets',
#       'alias': 'NYJ',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4427'},
#      'broadcast': {'network': 'CBS'}},
#     {'id': '2f178e5f-d746-45af-8578-07ed1e17b906',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306296',
#      'venue': {'id': '90c38d91-3774-4f5d-82ca-1c806828219f',
#       'name': 'FirstEnergy Stadium',
#       'city': 'Cleveland',
#       'state': 'OH',
#       'country': 'USA',
#       'zip': '44114',
#       'address': '100 Alfred Lerner Way',
#       'capacity': 67895,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8177',
#       'location': {'lat': '41.506054', 'lng': '-81.700004'}},
#      'home': {'id': 'd5a2eb42-8065-4174-ab79-0a6fa820e35e',
#       'name': 'Cleveland Browns',
#       'alias': 'CLE',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4417'},
#      'away': {'id': 'ad4ae08f-d808-42d5-a1e6-e9bc4e34d123',
#       'name': 'Cincinnati Bengals',
#       'alias': 'CIN',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4416'},
#      'broadcast': {'network': 'CBS'}},
#     {'id': '4760c906-4a2f-4026-b351-88b59d5ad50c',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306288',
#      'venue': {'id': '1f2d393b-2291-4835-a412-0714966ea245',
#       'name': 'Mercedes-Benz Stadium',
#       'city': 'Atlanta',
#       'state': 'GA',
#       'country': 'USA',
#       'zip': '30313',
#       'address': '441 Martin Luther King Jr Drive NW',
#       'capacity': 71000,
#       'surface': 'artificial',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:20343',
#       'location': {'lat': '33.757368', 'lng': '-84.401008'}},
#      'home': {'id': 'e6aa13a4-0055-48a9-bc41-be28dc106929',
#       'name': 'Atlanta Falcons',
#       'alias': 'ATL',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4393'},
#      'away': {'id': '0d855753-ea21-4953-89f9-0e20aff9eb73',
#       'name': 'New Orleans Saints',
#       'alias': 'NO',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4425'},
#      'broadcast': {'network': 'FOX'}},
#     {'id': '4a930251-20bb-4127-86b8-b7921cc2ce09',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306280',
#      'venue': {'id': '5d4c85c7-d84e-4e10-bd6a-8a15ebecca5c',
#       'name': 'MetLife Stadium',
#       'city': 'East Rutherford',
#       'state': 'NJ',
#       'country': 'USA',
#       'zip': '07073',
#       'address': 'One MetLife Stadium Drive',
#       'capacity': 82500,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:1981',
#       'location': {'lat': '40.813611', 'lng': '-74.074444'}},
#      'home': {'id': '04aa1c9d-66da-489d-b16a-1dee3f2eec4d',
#       'name': 'New York Giants',
#       'alias': 'NYG',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4426'},
#      'away': {'id': '22052ff7-c065-42ee-bc8f-c4691c50e624',
#       'name': 'Washington Football Team',
#       'alias': 'WAS',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4432'},
#      'broadcast': {'network': 'FOX'}},
#     {'id': '7506db5b-5c02-4a83-9d04-37337060bc75',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306274',
#      'venue': {'id': '4fa8c29c-6626-464c-8540-314ed7535e1b',
#       'name': 'Lincoln Financial Field',
#       'city': 'Philadelphia',
#       'state': 'PA',
#       'country': 'USA',
#       'zip': '19148',
#       'address': '1020 Pattison Avenue',
#       'capacity': 69596,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:1833',
#       'location': {'lat': '39.900872', 'lng': '-75.167311'}},
#      'home': {'id': '386bdbf9-9eea-4869-bb9a-274b0bc66e80',
#       'name': 'Philadelphia Eagles',
#       'alias': 'PHI',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4428'},
#      'away': {'id': 'e627eec7-bbae-4fa4-8e73-8e1d6bc5c060',
#       'name': 'Dallas Cowboys',
#       'alias': 'DAL',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4392'},
#      'broadcast': {'network': 'FOX'}},
#     {'id': '81036690-31a7-40bd-ad10-00e4e0f41c69',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306284',
#      'venue': {'id': '6fccc39c-80bc-4c81-83d9-2d5a848c8c09',
#       'name': 'Raymond James Stadium',
#       'city': 'Tampa',
#       'state': 'FL',
#       'country': 'USA',
#       'zip': '33607',
#       'address': '4201 North Dale Mabry Highway',
#       'capacity': 65890,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8205',
#       'location': {'lat': '27.976211', 'lng': '-82.503625'}},
#      'home': {'id': '4254d319-1bc7-4f81-b4ab-b5e6f3402b69',
#       'name': 'Tampa Bay Buccaneers',
#       'alias': 'TB',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4388'},
#      'away': {'id': 'f14bf5cc-9a82-4a38-bc15-d39f75ed5314',
#       'name': 'Carolina Panthers',
#       'alias': 'CAR',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4415'},
#      'broadcast': {'network': 'FOX'}},
#     {'id': '8443dad7-4a4e-4536-a394-fcefc5150b13',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306282',
#      'venue': {'id': 'f5ff00d4-1ed8-4918-bf73-13d66d510f98',
#       'name': 'U.S. Bank Stadium',
#       'city': 'Minneapolis',
#       'state': 'MN',
#       'country': 'USA',
#       'zip': '55415',
#       'address': '900 S 5th Street',
#       'capacity': 66655,
#       'surface': 'artificial',
#       'roof_type': 'dome',
#       'sr_id': 'sr:venue:18423',
#       'location': {'lat': '44.973686', 'lng': '-93.257458'}},
#      'home': {'id': '33405046-04ee-4058-a950-d606f8c30852',
#       'name': 'Minnesota Vikings',
#       'alias': 'MIN',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4423'},
#      'away': {'id': '7b112545-38e6-483c-a55c-96cf6ee49cb8',
#       'name': 'Chicago Bears',
#       'alias': 'CHI',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4391'},
#      'broadcast': {'network': 'FOX'}},
#     {'id': '9b5b6a66-e9de-4254-a938-114116d8b877',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306286',
#      'venue': {'id': '50a5c833-1570-4c38-abc7-7914cf87dbde',
#       'name': 'Hard Rock Stadium',
#       'city': 'Miami Gardens',
#       'state': 'FL',
#       'country': 'USA',
#       'zip': '33056',
#       'address': '2269 Northwest 199th Street',
#       'capacity': 65326,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:21306',
#       'location': {'lat': '25.958025', 'lng': '-80.238724'}},
#      'home': {'id': '4809ecb0-abd3-451d-9c4a-92a90b83ca06',
#       'name': 'Miami Dolphins',
#       'alias': 'MIA',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4287'},
#      'away': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#       'name': 'New England Patriots',
#       'alias': 'NE',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4424'},
#      'broadcast': {'network': 'CBS'}},
#     {'id': 'ccc0f33f-e8d8-4d56-ba5c-0052a7cbe64e',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306290',
#      'venue': {'id': '6a72e5ca-33d0-40af-8e6b-b32a4d3d9346',
#       'name': 'NRG Stadium',
#       'city': 'Houston',
#       'state': 'TX',
#       'country': 'USA',
#       'zip': '77054',
#       'address': 'One Reliant Park',
#       'capacity': 72220,
#       'surface': 'artificial',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:2402',
#       'location': {'lat': '29.684735', 'lng': '-95.410725'}},
#      'home': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#       'name': 'Houston Texans',
#       'alias': 'HOU',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4324'},
#      'away': {'id': 'd26a1ca5-722d-4274-8f97-c92e49c96315',
#       'name': 'Tennessee Titans',
#       'alias': 'TEN',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:367364'},
#      'broadcast': {'network': 'CBS'}},
#     {'id': 'ee4b83c6-e03b-4f6c-bffe-6aad9aad3df0',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306278',
#      'venue': {'id': '4c5c036d-dd3d-4183-b595-71a43a97560f',
#       'name': 'TIAA Bank Field',
#       'city': 'Jacksonville',
#       'state': 'FL',
#       'country': 'USA',
#       'zip': '32202',
#       'address': 'One EverBank Field Drive',
#       'capacity': 69132,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8187',
#       'location': {'lat': '30.324027', 'lng': '-81.637239'}},
#      'home': {'id': 'f7ddd7fa-0bae-4f90-bc8e-669e4d6cf2de',
#       'name': 'Jacksonville Jaguars',
#       'alias': 'JAC',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4386'},
#      'away': {'id': '82cf9565-6eb9-4f01-bdbd-5aa0d472fcd9',
#       'name': 'Indianapolis Colts',
#       'alias': 'IND',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4421'},
#      'broadcast': {'network': 'CBS'}},
#     {'id': 'f8a5bc21-3002-4734-9bf2-89a1e4710dc1',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T18:00:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306276',
#      'venue': {'id': '6e3bcf22-277d-4c06-b019-62aded51654f',
#       'name': 'Ford Field',
#       'city': 'Detroit',
#       'state': 'MI',
#       'country': 'USA',
#       'zip': '48226',
#       'address': '2000 Brush Street',
#       'capacity': 65000,
#       'surface': 'artificial',
#       'roof_type': 'dome',
#       'sr_id': 'sr:venue:8181',
#       'location': {'lat': '42.339958', 'lng': '-83.045636'}},
#      'home': {'id': 'c5a59daa-53a7-4de0-851f-fb12be893e9e',
#       'name': 'Detroit Lions',
#       'alias': 'DET',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4419'},
#      'away': {'id': 'a20471b4-a8d9-40c7-95ad-90cc30e46932',
#       'name': 'Green Bay Packers',
#       'alias': 'GB',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4420'},
#      'broadcast': {'network': 'FOX'}},
#     {'id': '29af4271-3638-4dd8-ad0b-d6fea2045473',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T21:25:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306298',
#      'venue': {'id': '53d42601-5dfb-40a7-bd94-da2c1d3a75e4',
#       'name': 'Allegiant Stadium',
#       'city': 'Las Vegas',
#       'state': 'NV',
#       'country': 'USA',
#       'zip': '89118',
#       'address': '3333 Al Davis Way',
#       'capacity': 65000,
#       'surface': 'turf',
#       'roof_type': 'dome',
#       'sr_id': 'sr:venue:51543',
#       'location': {'lat': '36.090852', 'lng': '-115.183339'}},
#      'home': {'id': '7d4fcc64-9cb5-4d1b-8e75-8a906d1e1576',
#       'name': 'Las Vegas Raiders',
#       'alias': 'LV',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4390'},
#      'away': {'id': '1f6dcffb-9823-43cd-9ff4-e7a8466749b5',
#       'name': 'Los Angeles Chargers',
#       'alias': 'LAC',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4429'},
#      'broadcast': {'network': 'CBS'}},
#     {'id': '97e44ef2-1e33-4c87-96f0-38278451df09',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T21:25:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306300',
#      'venue': {'id': '790c1f04-73c6-4f6f-8b1e-78a62260be90',
#       'name': 'SoFi Stadium',
#       'city': 'Inglewood',
#       'state': 'CA',
#       'country': 'USA',
#       'zip': '90301',
#       'address': '1000 S Prairie Ave',
#       'capacity': 70240,
#       'surface': 'artificial',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:52183',
#       'location': {'lat': '33.953536', 'lng': '-118.338734'}},
#      'home': {'id': '2eff2a03-54d4-46ba-890e-2bc3925548f3',
#       'name': 'Los Angeles Rams',
#       'alias': 'LA',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4387'},
#      'away': {'id': 'f0e724b0-4cbf-495a-be47-013907608da9',
#       'name': 'San Francisco 49ers',
#       'alias': 'SF',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4389'},
#      'broadcast': {'network': 'FOX'}},
#     {'id': '9ae2e651-42dd-4092-9b65-c392e45331b6',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T21:25:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306302',
#      'venue': {'id': '6589e61d-ef1e-4e30-91b5-9acd2072b8a0',
#       'name': 'Empower Field at Mile High',
#       'city': 'Denver',
#       'state': 'CO',
#       'country': 'USA',
#       'zip': '80204',
#       'address': '1701 Mile High Stadium Circle',
#       'capacity': 76125,
#       'surface': 'turf',
#       'roof_type': 'outdoor',
#       'sr_id': 'sr:venue:8179',
#       'location': {'lat': '39.743865', 'lng': '-105.020158'}},
#      'home': {'id': 'ce92bd47-93d5-4fe9-ada4-0fc681e6caa0',
#       'name': 'Denver Broncos',
#       'alias': 'DEN',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4418'},
#      'away': {'id': '6680d28d-d4d2-49f6-aace-5292d3ec02c2',
#       'name': 'Kansas City Chiefs',
#       'alias': 'KC',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4422'},
#      'broadcast': {'network': 'CBS'}},
#     {'id': 'e9cb4364-2b43-4a92-8763-56276fd74df5',
#      'status': 'flex-schedule',
#      'scheduled': '2022-01-09T21:25:00+00:00',
#      'entry_mode': 'LDE',
#      'sr_id': 'sr:match:27306304',
#      'venue': {'id': 'f8e4d2ab-53f9-4e9f-8c4a-9bc278094a84',
#       'name': 'State Farm Stadium',
#       'city': 'Glendale',
#       'state': 'AZ',
#       'country': 'USA',
#       'zip': '85305',
#       'address': 'One Cardinals Drive',
#       'capacity': 63400,
#       'surface': 'turf',
#       'roof_type': 'retractable_dome',
#       'sr_id': 'sr:venue:8165',
#       'location': {'lat': '33.527765', 'lng': '-112.262090'}},
#      'home': {'id': 'de760528-1dc0-416a-a978-b510d20692ff',
#       'name': 'Arizona Cardinals',
#       'alias': 'ARI',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4412'},
#      'away': {'id': '3d08af9e-c767-4f88-a7dc-b920c6d2b4a8',
#       'name': 'Seattle Seahawks',
#       'alias': 'SEA',
#       'game_number': 17,
#       'sr_id': 'sr:competitor:4430'},
#      'broadcast': {'network': 'FOX'}}]}],
#  '_comment': 'Generation started @ 2021-10-28 18:26:21 UTC ended @ 2021-10-28 18:26:21 UTC'}

# %%
week_1_games = data['weeks'][0]['games']

# %%
week_1_games
# Out:
# [{'id': '01d1210a-d34e-4dc7-9c24-bbd25f5fb3ad',
#   'status': 'closed',
#   'scheduled': '2021-09-10T00:20:00+00:00',
#   'attendance': 65566,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299744',
#   'venue': {'id': '6fccc39c-80bc-4c81-83d9-2d5a848c8c09',
#    'name': 'Raymond James Stadium',
#    'city': 'Tampa',
#    'state': 'FL',
#    'country': 'USA',
#    'zip': '33607',
#    'address': '4201 North Dale Mabry Highway',
#    'capacity': 65890,
#    'surface': 'turf',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:8205',
#    'location': {'lat': '27.976211', 'lng': '-82.503625'}},
#   'home': {'id': '4254d319-1bc7-4f81-b4ab-b5e6f3402b69',
#    'name': 'Tampa Bay Buccaneers',
#    'alias': 'TB',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4388'},
#   'away': {'id': 'e627eec7-bbae-4fa4-8e73-8e1d6bc5c060',
#    'name': 'Dallas Cowboys',
#    'alias': 'DAL',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4392'},
#   'broadcast': {'network': 'NBC'},
#   'weather': {'condition': 'Partly cloudy',
#    'humidity': 85,
#    'temp': 82,
#    'wind': {'speed': 9, 'direction': 'WSW'}},
#   'scoring': {'home_points': 31,
#    'away_points': 29,
#    'periods': [{'period_type': 'quarter',
#      'id': '4f82eb0e-21dc-4153-aaf3-0e02530322da',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 7,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'dbfd0034-6a25-41e2-a740-a0774342985c',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 14,
#      'away_points': 9},
#     {'period_type': 'quarter',
#      'id': 'a3aa9f44-287e-4161-971f-9ce598c416b2',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 7,
#      'away_points': 10},
#     {'period_type': 'quarter',
#      'id': '689c4991-d979-4960-bd3b-1c400ddb4ff6',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 3,
#      'away_points': 3}]}},
#  {'id': '11635c85-7cc5-429c-a13a-168b8d92f01f',
#   'status': 'closed',
#   'scheduled': '2021-09-12T17:00:00+00:00',
#   'attendance': 67216,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299762',
#   'venue': {'id': '5295c1b7-c85c-49cb-9569-1707c65324e5',
#    'name': 'Nissan Stadium',
#    'city': 'Nashville',
#    'state': 'TN',
#    'country': 'USA',
#    'zip': '37213',
#    'address': 'One Titans Way',
#    'capacity': 69143,
#    'surface': 'turf',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:8207',
#    'location': {'lat': '36.166367', 'lng': '-86.771223'}},
#   'home': {'id': 'd26a1ca5-722d-4274-8f97-c92e49c96315',
#    'name': 'Tennessee Titans',
#    'alias': 'TEN',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:367364'},
#   'away': {'id': 'de760528-1dc0-416a-a978-b510d20692ff',
#    'name': 'Arizona Cardinals',
#    'alias': 'ARI',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4412'},
#   'broadcast': {'network': 'CBS'},
#   'weather': {'condition': 'Sunny',
#    'humidity': 55,
#    'temp': 82,
#    'wind': {'speed': 8, 'direction': 'SW'}},
#   'scoring': {'home_points': 13,
#    'away_points': 38,
#    'periods': [{'period_type': 'quarter',
#      'id': '6fd10b65-e0f8-4a3e-b1f8-1419f5763fb1',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 0,
#      'away_points': 10},
#     {'period_type': 'quarter',
#      'id': '7a715518-03a6-4837-983f-f0f48194f677',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 6,
#      'away_points': 14},
#     {'period_type': 'quarter',
#      'id': 'afc87ebb-3662-4735-8a49-28226f045bc5',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 7,
#      'away_points': 14},
#     {'period_type': 'quarter',
#      'id': 'fc9b3351-7cbf-405e-8d41-625f2bb07013',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 0,
#      'away_points': 0}]}},
#  {'id': '308bce88-f5d4-4fac-ad23-d6a47abde7be',
#   'status': 'closed',
#   'scheduled': '2021-09-12T17:00:00+00:00',
#   'attendance': 68105,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299750',
#   'venue': {'id': '6a72e5ca-33d0-40af-8e6b-b32a4d3d9346',
#    'name': 'NRG Stadium',
#    'city': 'Houston',
#    'state': 'TX',
#    'country': 'USA',
#    'zip': '77054',
#    'address': 'One Reliant Park',
#    'capacity': 72220,
#    'surface': 'artificial',
#    'roof_type': 'retractable_dome',
#    'sr_id': 'sr:venue:2402',
#    'location': {'lat': '29.684735', 'lng': '-95.410725'}},
#   'home': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#    'name': 'Houston Texans',
#    'alias': 'HOU',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4324'},
#   'away': {'id': 'f7ddd7fa-0bae-4f90-bc8e-669e4d6cf2de',
#    'name': 'Jacksonville Jaguars',
#    'alias': 'JAC',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4386'},
#   'broadcast': {'network': 'CBS'},
#   'weather': {'condition': 'Partly cloudy',
#    'humidity': 58,
#    'temp': 84,
#    'wind': {'speed': 4, 'direction': 'N'}},
#   'scoring': {'home_points': 37,
#    'away_points': 21,
#    'periods': [{'period_type': 'quarter',
#      'id': '9e5d1c6d-80fd-4259-b28e-a2f0a0baabb4',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 14,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': 'a7862650-436d-44be-a02d-81f92b16c7e4',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 13,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'cd7f87d8-ba1e-43b9-ba82-a6c77ba30a96',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 7,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'd0dcfdc8-200d-44c6-b2a1-8c5d4ef5f3b3',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 3,
#      'away_points': 7}]}},
#  {'id': '41145b5f-b1b9-4e9e-95bb-c3292aa791c3',
#   'status': 'closed',
#   'scheduled': '2021-09-12T17:00:00+00:00',
#   'attendance': 56525,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299766',
#   'venue': {'id': 'b87a1595-d3c8-48ea-8a53-0aab6378a64a',
#    'name': 'Paul Brown Stadium',
#    'city': 'Cincinnati',
#    'state': 'OH',
#    'country': 'USA',
#    'zip': '45202',
#    'address': 'One Paul Brown Stadium',
#    'capacity': 65515,
#    'surface': 'artificial',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:8175',
#    'location': {'lat': '39.095413', 'lng': '-84.516204'}},
#   'home': {'id': 'ad4ae08f-d808-42d5-a1e6-e9bc4e34d123',
#    'name': 'Cincinnati Bengals',
#    'alias': 'CIN',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4416'},
#   'away': {'id': '33405046-04ee-4058-a950-d606f8c30852',
#    'name': 'Minnesota Vikings',
#    'alias': 'MIN',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4423'},
#   'broadcast': {'network': 'FOX'},
#   'weather': {'condition': 'Sunny',
#    'humidity': 54,
#    'temp': 81,
#    'wind': {'speed': 15, 'direction': 'SSW'}},
#   'scoring': {'home_points': 27,
#    'away_points': 24,
#    'periods': [{'period_type': 'quarter',
#      'id': 'bb008516-8b0a-44a0-870f-fe1762183618',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 0,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': '72327703-a1b1-4cfa-a0f2-ee16f68b8828',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 14,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'e405ec90-be3d-4557-b13a-9c1f038464b8',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 7,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': '6b1e221c-9ef4-465e-b365-78693f7d8ad4',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 3,
#      'away_points': 10},
#     {'period_type': 'overtime',
#      'id': '9e82ec0b-9e32-4d59-99ce-5b839f414b3d',
#      'number': 1,
#      'sequence': 5,
#      'home_points': 3,
#      'away_points': 0}]}},
#  {'id': '616216d2-6e3f-41dd-9a47-1b7ce1e6b0d7',
#   'status': 'closed',
#   'scheduled': '2021-09-12T17:00:00+00:00',
#   'attendance': 63347,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299772',
#   'venue': {'id': '6ed18563-53e0-46c2-a91d-12d73a16456d',
#    'name': 'Lucas Oil Stadium',
#    'city': 'Indianapolis',
#    'state': 'IN',
#    'country': 'USA',
#    'zip': '46225',
#    'address': '500 South Capitol Avenue',
#    'capacity': 67000,
#    'surface': 'artificial',
#    'roof_type': 'retractable_dome',
#    'sr_id': 'sr:venue:8185',
#    'location': {'lat': '39.760008', 'lng': '-86.163906'}},
#   'home': {'id': '82cf9565-6eb9-4f01-bdbd-5aa0d472fcd9',
#    'name': 'Indianapolis Colts',
#    'alias': 'IND',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4421'},
#   'away': {'id': '3d08af9e-c767-4f88-a7dc-b920c6d2b4a8',
#    'name': 'Seattle Seahawks',
#    'alias': 'SEA',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4430'},
#   'broadcast': {'network': 'FOX'},
#   'weather': {'condition': 'Partly cloudy',
#    'humidity': 51,
#    'temp': 81,
#    'wind': {'speed': 19, 'direction': 'SW'}},
#   'scoring': {'home_points': 16,
#    'away_points': 28,
#    'periods': [{'period_type': 'quarter',
#      'id': 'b92ab6a8-d7b6-40cb-9078-a8b7400e62d0',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 3,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': '531da782-75c7-4664-adba-8796170ef2ae',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 7,
#      'away_points': 14},
#     {'period_type': 'quarter',
#      'id': 'e8575957-94be-42ac-bc21-255a8a6d1581',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 0,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': 'cdf4379e-ab2c-4e1a-872e-ff3374046805',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 6,
#      'away_points': 7}]}},
#  {'id': '63cca58f-b316-4c57-9cea-fc056c665c6c',
#   'status': 'closed',
#   'scheduled': '2021-09-12T17:00:00+00:00',
#   'attendance': 69787,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299754',
#   'venue': {'id': 'e9e0828e-37fc-4238-a317-49037577dd55',
#    'name': 'Highmark Stadium',
#    'city': 'Orchard Park',
#    'state': 'NY',
#    'country': 'USA',
#    'zip': '14127',
#    'address': 'One Bills Drive',
#    'capacity': 71608,
#    'surface': 'artificial',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:8171',
#    'location': {'lat': '42.773826', 'lng': '-78.786589'}},
#   'home': {'id': '768c92aa-75ff-4a43-bcc0-f2798c2e1724',
#    'name': 'Buffalo Bills',
#    'alias': 'BUF',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4376'},
#   'away': {'id': 'cb2f9f1f-ac67-424e-9e72-1475cb0ed398',
#    'name': 'Pittsburgh Steelers',
#    'alias': 'PIT',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4345'},
#   'broadcast': {'network': 'CBS'},
#   'weather': {'condition': 'Overcast',
#    'humidity': 79,
#    'temp': 73,
#    'wind': {'speed': 17, 'direction': 'WSW'}},
#   'scoring': {'home_points': 16,
#    'away_points': 23,
#    'periods': [{'period_type': 'quarter',
#      'id': '56e20382-bcce-4030-9450-9d03304171cf',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 3,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': 'd40362fe-eac7-452c-a927-d981912bc250',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 7,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': 'c3192fc8-f1d9-4a78-b860-8c896e19d44f',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 0,
#      'away_points': 6},
#     {'period_type': 'quarter',
#      'id': '7a575829-2ae9-430c-b208-beeafb3aa9c1',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 6,
#      'away_points': 17}]}},
#  {'id': '90d6aa77-e522-4c20-970c-01a61bc04e36',
#   'status': 'closed',
#   'scheduled': '2021-09-12T17:00:00+00:00',
#   'attendance': 59374,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299768',
#   'venue': {'id': '6e3bcf22-277d-4c06-b019-62aded51654f',
#    'name': 'Ford Field',
#    'city': 'Detroit',
#    'state': 'MI',
#    'country': 'USA',
#    'zip': '48226',
#    'address': '2000 Brush Street',
#    'capacity': 65000,
#    'surface': 'artificial',
#    'roof_type': 'dome',
#    'sr_id': 'sr:venue:8181',
#    'location': {'lat': '42.339958', 'lng': '-83.045636'}},
#   'home': {'id': 'c5a59daa-53a7-4de0-851f-fb12be893e9e',
#    'name': 'Detroit Lions',
#    'alias': 'DET',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4419'},
#   'away': {'id': 'f0e724b0-4cbf-495a-be47-013907608da9',
#    'name': 'San Francisco 49ers',
#    'alias': 'SF',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4389'},
#   'broadcast': {'network': 'FOX'},
#   'weather': {'condition': 'Partly cloudy',
#    'humidity': 65,
#    'temp': 79,
#    'wind': {'speed': 8, 'direction': 'W'}},
#   'scoring': {'home_points': 33,
#    'away_points': 41,
#    'periods': [{'period_type': 'quarter',
#      'id': 'acb71ad3-a484-4210-b8c2-da8d9f12dbbb',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 0,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'ebb73243-96e6-40bd-8d8e-af9ffc00f17c',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 10,
#      'away_points': 24},
#     {'period_type': 'quarter',
#      'id': '2fbaa5a3-ec4b-4a32-8308-c207eb30ec5e',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 7,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': '208f3ee6-bd79-40e8-89f5-c641f73f87a5',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 16,
#      'away_points': 3}]}},
#  {'id': 'a60b9775-cc49-4a09-9382-31fd6efdf4e7',
#   'status': 'closed',
#   'scheduled': '2021-09-12T17:00:00+00:00',
#   'attendance': 52753,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299764',
#   'venue': {'id': '7c11bb2d-4a53-4842-b842-0f1c63ed78e9',
#    'name': 'FedExField',
#    'city': 'Landover',
#    'state': 'MD',
#    'country': 'USA',
#    'zip': '20785',
#    'address': '1600 FedEx Way',
#    'capacity': 82000,
#    'surface': 'turf',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:6652',
#    'location': {'lat': '38.907724', 'lng': '-76.864613'}},
#   'home': {'id': '22052ff7-c065-42ee-bc8f-c4691c50e624',
#    'name': 'Washington Football Team',
#    'alias': 'WAS',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4432'},
#   'away': {'id': '1f6dcffb-9823-43cd-9ff4-e7a8466749b5',
#    'name': 'Los Angeles Chargers',
#    'alias': 'LAC',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4429'},
#   'broadcast': {'network': 'CBS'},
#   'weather': {'condition': 'Sunny',
#    'humidity': 49,
#    'temp': 81,
#    'wind': {'speed': 4, 'direction': 'S'}},
#   'scoring': {'home_points': 16,
#    'away_points': 20,
#    'periods': [{'period_type': 'quarter',
#      'id': '577f470a-db07-47d2-8976-eb4e2b6e01b4',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 3,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'f33a1c03-f5c0-49f6-afc7-9869d347c234',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 6,
#      'away_points': 6},
#     {'period_type': 'quarter',
#      'id': '7a0200c4-2361-4f8c-8d61-306da6a53d1e',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 7,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': '0a4294f6-9235-4dbd-9249-dd8e1342f029',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 0,
#      'away_points': 7}]}},
#  {'id': 'a74cb1bc-23a4-482e-a389-a622fa05faff',
#   'status': 'closed',
#   'scheduled': '2021-09-12T17:00:00+00:00',
#   'attendance': 70211,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299760',
#   'venue': {'id': '39be9ed4-3292-49ac-8699-a381de3a4969',
#    'name': 'Bank of America Stadium',
#    'city': 'Charlotte',
#    'state': 'NC',
#    'country': 'USA',
#    'zip': '28202',
#    'address': '800 South Mint Street',
#    'capacity': 75419,
#    'surface': 'artificial',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:8173',
#    'location': {'lat': '35.225937', 'lng': '-80.853133'}},
#   'home': {'id': 'f14bf5cc-9a82-4a38-bc15-d39f75ed5314',
#    'name': 'Carolina Panthers',
#    'alias': 'CAR',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4415'},
#   'away': {'id': '5fee86ae-74ab-4bdd-8416-42a9dd9964f3',
#    'name': 'New York Jets',
#    'alias': 'NYJ',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4427'},
#   'broadcast': {'network': 'CBS'},
#   'weather': {'condition': 'Sunny',
#    'humidity': 51,
#    'temp': 81,
#    'wind': {'speed': 0, 'direction': 'WSW'}},
#   'scoring': {'home_points': 19,
#    'away_points': 14,
#    'periods': [{'period_type': 'quarter',
#      'id': '85a7b208-ac3b-4332-ad61-dbf46fa10176',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 0,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': '25cd6e15-e731-4498-9dc8-79673f934af5',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 16,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': '4d7b7635-17a1-4c15-b857-28c9a044e3bd',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 0,
#      'away_points': 8},
#     {'period_type': 'quarter',
#      'id': '91eb8923-38ea-49ef-8d13-5c6c766f4fb8',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 3,
#      'away_points': 6}]}},
#  {'id': 'fb4085e6-3290-49d1-84e4-e254f817cd7f',
#   'status': 'closed',
#   'scheduled': '2021-09-12T17:00:00+00:00',
#   'attendance': 68633,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299770',
#   'venue': {'id': '1f2d393b-2291-4835-a412-0714966ea245',
#    'name': 'Mercedes-Benz Stadium',
#    'city': 'Atlanta',
#    'state': 'GA',
#    'country': 'USA',
#    'zip': '30313',
#    'address': '441 Martin Luther King Jr Drive NW',
#    'capacity': 71000,
#    'surface': 'artificial',
#    'roof_type': 'retractable_dome',
#    'sr_id': 'sr:venue:20343',
#    'location': {'lat': '33.757368', 'lng': '-84.401008'}},
#   'home': {'id': 'e6aa13a4-0055-48a9-bc41-be28dc106929',
#    'name': 'Atlanta Falcons',
#    'alias': 'ATL',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4393'},
#   'away': {'id': '386bdbf9-9eea-4869-bb9a-274b0bc66e80',
#    'name': 'Philadelphia Eagles',
#    'alias': 'PHI',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4428'},
#   'broadcast': {'network': 'FOX'},
#   'weather': {'condition': 'Sunny',
#    'humidity': 72,
#    'temp': 79,
#    'wind': {'speed': 0, 'direction': 'E'}},
#   'scoring': {'home_points': 6,
#    'away_points': 32,
#    'periods': [{'period_type': 'quarter',
#      'id': '716c0a22-c6f0-4adf-99a6-47a424fa567e',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 3,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'd5670255-31dc-4097-b58e-7ca63907e828',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 3,
#      'away_points': 8},
#     {'period_type': 'quarter',
#      'id': 'ebb2f943-1166-4849-97b1-19b9c3617a34',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 0,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'f5f37e69-b2ce-456d-af45-49b506f2901d',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 0,
#      'away_points': 10}]}},
#  {'id': '22a36a47-e07c-42d9-b5d8-ee1709b68a14',
#   'status': 'closed',
#   'scheduled': '2021-09-12T20:25:00+00:00',
#   'attendance': 72973,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299774',
#   'venue': {'id': '2ec4c411-dac2-403d-b091-6b6aa4a0a914',
#    'name': 'GEHA Field at Arrowhead Stadium',
#    'city': 'Kansas City',
#    'state': 'MO',
#    'country': 'USA',
#    'zip': '64129',
#    'address': 'One Arrowhead Drive',
#    'capacity': 76416,
#    'surface': 'turf',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:8189',
#    'location': {'lat': '39.049019', 'lng': '-94.484140'}},
#   'home': {'id': '6680d28d-d4d2-49f6-aace-5292d3ec02c2',
#    'name': 'Kansas City Chiefs',
#    'alias': 'KC',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4422'},
#   'away': {'id': 'd5a2eb42-8065-4174-ab79-0a6fa820e35e',
#    'name': 'Cleveland Browns',
#    'alias': 'CLE',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4417'},
#   'broadcast': {'network': 'CBS'},
#   'weather': {'condition': 'Sunny',
#    'humidity': 43,
#    'temp': 88,
#    'wind': {'speed': 8, 'direction': 'S'}},
#   'scoring': {'home_points': 33,
#    'away_points': 29,
#    'periods': [{'period_type': 'quarter',
#      'id': '995950b6-b800-41a2-a46c-e50396e0de26',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 3,
#      'away_points': 8},
#     {'period_type': 'quarter',
#      'id': '119132c5-d4bc-4919-aa66-9d06f5a2ec24',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 7,
#      'away_points': 14},
#     {'period_type': 'quarter',
#      'id': 'f88cfce1-5fb8-4a42-921e-efc2c1993c9c',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 10,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': '94c9e554-808b-43d2-98b3-a6a8fded48dd',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 13,
#      'away_points': 7}]}},
#  {'id': '633711b1-a6c4-46c1-99f2-3279c744ff58',
#   'status': 'closed',
#   'scheduled': '2021-09-12T20:25:00+00:00',
#   'attendance': 35242,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299780',
#   'venue': {'id': '4c5c036d-dd3d-4183-b595-71a43a97560f',
#    'name': 'TIAA Bank Field',
#    'city': 'Jacksonville',
#    'state': 'FL',
#    'country': 'USA',
#    'zip': '32202',
#    'address': 'One EverBank Field Drive',
#    'capacity': 69132,
#    'surface': 'turf',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:8187',
#    'location': {'lat': '30.324027', 'lng': '-81.637239'}},
#   'home': {'id': '0d855753-ea21-4953-89f9-0e20aff9eb73',
#    'name': 'New Orleans Saints',
#    'alias': 'NO',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4425'},
#   'away': {'id': 'a20471b4-a8d9-40c7-95ad-90cc30e46932',
#    'name': 'Green Bay Packers',
#    'alias': 'GB',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4420'},
#   'broadcast': {'network': 'FOX'},
#   'weather': {'condition': 'Partly cloudy',
#    'humidity': 57,
#    'temp': 86,
#    'wind': {'speed': 9, 'direction': 'ENE'}},
#   'scoring': {'home_points': 38,
#    'away_points': 3,
#    'periods': [{'period_type': 'quarter',
#      'id': 'a85a769c-cd99-4d33-a191-1711328e6766',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 3,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': '9d9f2e0a-dd5b-4f3b-a2cd-33f6d2066528',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 14,
#      'away_points': 3},
#     {'period_type': 'quarter',
#      'id': '9c8dfb5c-1a04-4b92-9286-3e61ad7a5355',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 7,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': '9d9b9a4a-5979-4aaf-a6b0-3680c3e79577',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 14,
#      'away_points': 0}]}},
#  {'id': '8c17016f-1c58-4976-a6bd-0ab920a97315',
#   'status': 'closed',
#   'scheduled': '2021-09-12T20:25:00+00:00',
#   'attendance': 74119,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299778',
#   'venue': {'id': '5d4c85c7-d84e-4e10-bd6a-8a15ebecca5c',
#    'name': 'MetLife Stadium',
#    'city': 'East Rutherford',
#    'state': 'NJ',
#    'country': 'USA',
#    'zip': '07073',
#    'address': 'One MetLife Stadium Drive',
#    'capacity': 82500,
#    'surface': 'artificial',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:1981',
#    'location': {'lat': '40.813611', 'lng': '-74.074444'}},
#   'home': {'id': '04aa1c9d-66da-489d-b16a-1dee3f2eec4d',
#    'name': 'New York Giants',
#    'alias': 'NYG',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4426'},
#   'away': {'id': 'ce92bd47-93d5-4fe9-ada4-0fc681e6caa0',
#    'name': 'Denver Broncos',
#    'alias': 'DEN',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4418'},
#   'broadcast': {'network': 'FOX'},
#   'weather': {'condition': 'Sunny',
#    'humidity': 56,
#    'temp': 82,
#    'wind': {'speed': 19, 'direction': 'SW'}},
#   'scoring': {'home_points': 13,
#    'away_points': 27,
#    'periods': [{'period_type': 'quarter',
#      'id': 'bb5e46e7-026b-4a94-952e-5e14c79b5a29',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 0,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': '94f91d05-56b5-4539-9d05-5d40408ad6f7',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 7,
#      'away_points': 10},
#     {'period_type': 'quarter',
#      'id': '19998741-7f4d-480e-9271-f815206e7276',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 0,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': '8ac49efc-16fa-4909-bc81-a3db097fa6b2',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 6,
#      'away_points': 10}]}},
#  {'id': 'd2228d80-4cbf-46a2-8a2d-12fc2ef2935a',
#   'status': 'closed',
#   'scheduled': '2021-09-12T20:25:00+00:00',
#   'attendance': 65878,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299776',
#   'venue': {'id': 'e43310b1-cb82-4df9-8be5-e9b39637031b',
#    'name': 'Gillette Stadium',
#    'city': 'Foxborough',
#    'state': 'MA',
#    'country': 'USA',
#    'zip': '02035',
#    'address': 'One Patriot Place',
#    'capacity': 66829,
#    'surface': 'artificial',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:2379',
#    'location': {'lat': '42.090944', 'lng': '-71.264344'}},
#   'home': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#    'name': 'New England Patriots',
#    'alias': 'NE',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4424'},
#   'away': {'id': '4809ecb0-abd3-451d-9c4a-92a90b83ca06',
#    'name': 'Miami Dolphins',
#    'alias': 'MIA',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4287'},
#   'broadcast': {'network': 'CBS'},
#   'weather': {'condition': 'Sunny',
#    'humidity': 58,
#    'temp': 81,
#    'wind': {'speed': 15, 'direction': 'SSW'}},
#   'scoring': {'home_points': 16,
#    'away_points': 17,
#    'periods': [{'period_type': 'quarter',
#      'id': '55f430b7-d9ff-4656-9906-23c19df1f301',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 0,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'd7d6f07b-d37c-45d1-9d32-9cd5381757e1',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 10,
#      'away_points': 3},
#     {'period_type': 'quarter',
#      'id': '55bd246b-9913-4021-8c88-26608d0e7cc9',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 3,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': '5a40d631-1e73-49d7-babb-e8bef23b9008',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 3,
#      'away_points': 0}]}},
#  {'id': 'c9d06837-0ac3-4d3f-8d7f-eae447b531fa',
#   'status': 'closed',
#   'scheduled': '2021-09-13T00:20:00+00:00',
#   'attendance': 70445,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299782',
#   'venue': {'id': '790c1f04-73c6-4f6f-8b1e-78a62260be90',
#    'name': 'SoFi Stadium',
#    'city': 'Inglewood',
#    'state': 'CA',
#    'country': 'USA',
#    'zip': '90301',
#    'address': '1000 S Prairie Ave',
#    'capacity': 70240,
#    'surface': 'artificial',
#    'roof_type': 'outdoor',
#    'sr_id': 'sr:venue:52183',
#    'location': {'lat': '33.953536', 'lng': '-118.338734'}},
#   'home': {'id': '2eff2a03-54d4-46ba-890e-2bc3925548f3',
#    'name': 'Los Angeles Rams',
#    'alias': 'LA',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4387'},
#   'away': {'id': '7b112545-38e6-483c-a55c-96cf6ee49cb8',
#    'name': 'Chicago Bears',
#    'alias': 'CHI',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4391'},
#   'broadcast': {'network': 'NBC'},
#   'weather': {'condition': 'Sunny',
#    'humidity': 61,
#    'temp': 72,
#    'wind': {'speed': 12, 'direction': 'W'}},
#   'scoring': {'home_points': 34,
#    'away_points': 14,
#    'periods': [{'period_type': 'quarter',
#      'id': 'e9199bf5-7f1c-4593-82e1-2fa4e24db8ee',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 10,
#      'away_points': 0},
#     {'period_type': 'quarter',
#      'id': '49a59e28-0257-4de4-b30a-fff93889e574',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 3,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'f6df02b4-212f-4f25-a9a4-467755dad6c2',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 14,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': 'bdd8bf08-bc19-4da6-b1b9-41634f53abdc',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 7,
#      'away_points': 0}]}},
#  {'id': '6ec6abfa-46ed-4011-8068-5c1fea90a0ee',
#   'status': 'closed',
#   'scheduled': '2021-09-14T00:15:00+00:00',
#   'attendance': 61756,
#   'entry_mode': 'LDE',
#   'sr_id': 'sr:match:27299784',
#   'venue': {'id': '53d42601-5dfb-40a7-bd94-da2c1d3a75e4',
#    'name': 'Allegiant Stadium',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'country': 'USA',
#    'zip': '89118',
#    'address': '3333 Al Davis Way',
#    'capacity': 65000,
#    'surface': 'turf',
#    'roof_type': 'dome',
#    'sr_id': 'sr:venue:51543',
#    'location': {'lat': '36.090852', 'lng': '-115.183339'}},
#   'home': {'id': '7d4fcc64-9cb5-4d1b-8e75-8a906d1e1576',
#    'name': 'Las Vegas Raiders',
#    'alias': 'LV',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4390'},
#   'away': {'id': 'ebd87119-b331-4469-9ea6-d51fe3ce2f1c',
#    'name': 'Baltimore Ravens',
#    'alias': 'BAL',
#    'game_number': 1,
#    'sr_id': 'sr:competitor:4413'},
#   'broadcast': {'network': 'ESPN', 'satellite': '206'},
#   'weather': {'condition': 'Sunny',
#    'humidity': 8,
#    'temp': 102,
#    'wind': {'speed': 16, 'direction': 'SW'}},
#   'scoring': {'home_points': 33,
#    'away_points': 27,
#    'periods': [{'period_type': 'quarter',
#      'id': '092f3096-1a7e-44d8-b857-c415c652d96f',
#      'number': 1,
#      'sequence': 1,
#      'home_points': 0,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': '17a9d604-a492-41f0-8700-25677369882b',
#      'number': 2,
#      'sequence': 2,
#      'home_points': 10,
#      'away_points': 7},
#     {'period_type': 'quarter',
#      'id': '80f95556-6c66-4124-b092-8bd9c83eff3e',
#      'number': 3,
#      'sequence': 3,
#      'home_points': 0,
#      'away_points': 3},
#     {'period_type': 'quarter',
#      'id': '65c60887-d711-4c17-a313-3f66213f273a',
#      'number': 4,
#      'sequence': 4,
#      'home_points': 17,
#      'away_points': 10},
#     {'period_type': 'overtime',
#      'id': 'db516945-a555-4097-90b7-d52fdcd92ff8',
#      'number': 1,
#      'sequence': 5,
#      'home_points': 6,
#      'away_points': 0}]}}]

# %%
week_1_games[0]['id']
# Out:
# '01d1210a-d34e-4dc7-9c24-bbd25f5fb3ad'

# %%
week_1_games[0]['home']['name']
# Out:
# 'Tampa Bay Buccaneers'

# %%
week_1_games[0]['away']['name']
# Out:
# 'Dallas Cowboys'

# %%
week_1_games[0]['scoring']['home_points']
# Out:
# 31

# %%
week_1_games[0]['scoring']['away_points']
# Out:
# 29

# %%
week_1 = {}

games = dict()
keys = range(0,len(week_1_games))

for i in range(0,len(week_1_games)):
    games[i] = dict()
    games[i]['date'] = week_1_games[i]['scheduled']
    games[i]['game_id'] = week_1_games[i]['id']
    games[i]['home_team'] = week_1_games[i]['home']['name']
    games[i]['away_team'] = week_1_games[i]['away']['name']
    games[i]['home_score'] = week_1_games[i]['scoring']['home_points']
    games[i]['away_score'] = week_1_games[i]['scoring']['away_points']
df = pd.DataFrame.from_dict(games)

# %%
df = pd.DataFrame.from_dict(games, orient='index')

# %%
df
# Out:
#                          date                               game_id  \
# 0   2021-09-10T00:20:00+00:00  01d1210a-d34e-4dc7-9c24-bbd25f5fb3ad
# 1   2021-09-12T17:00:00+00:00  11635c85-7cc5-429c-a13a-168b8d92f01f
# 2   2021-09-12T17:00:00+00:00  308bce88-f5d4-4fac-ad23-d6a47abde7be
# 3   2021-09-12T17:00:00+00:00  41145b5f-b1b9-4e9e-95bb-c3292aa791c3
# 4   2021-09-12T17:00:00+00:00  616216d2-6e3f-41dd-9a47-1b7ce1e6b0d7
# 5   2021-09-12T17:00:00+00:00  63cca58f-b316-4c57-9cea-fc056c665c6c
# 6   2021-09-12T17:00:00+00:00  90d6aa77-e522-4c20-970c-01a61bc04e36
# 7   2021-09-12T17:00:00+00:00  a60b9775-cc49-4a09-9382-31fd6efdf4e7
# 8   2021-09-12T17:00:00+00:00  a74cb1bc-23a4-482e-a389-a622fa05faff
# 9   2021-09-12T17:00:00+00:00  fb4085e6-3290-49d1-84e4-e254f817cd7f
# 10  2021-09-12T20:25:00+00:00  22a36a47-e07c-42d9-b5d8-ee1709b68a14
# 11  2021-09-12T20:25:00+00:00  633711b1-a6c4-46c1-99f2-3279c744ff58
# 12  2021-09-12T20:25:00+00:00  8c17016f-1c58-4976-a6bd-0ab920a97315
# 13  2021-09-12T20:25:00+00:00  d2228d80-4cbf-46a2-8a2d-12fc2ef2935a
# 14  2021-09-13T00:20:00+00:00  c9d06837-0ac3-4d3f-8d7f-eae447b531fa
# 15  2021-09-14T00:15:00+00:00  6ec6abfa-46ed-4011-8068-5c1fea90a0ee
#
#                    home_team             away_team  home_score  away_score
# 0       Tampa Bay Buccaneers        Dallas Cowboys          31          29
# 1           Tennessee Titans     Arizona Cardinals          13          38
# 2             Houston Texans  Jacksonville Jaguars          37          21
# 3         Cincinnati Bengals     Minnesota Vikings          27          24
# 4         Indianapolis Colts      Seattle Seahawks          16          28
# 5              Buffalo Bills   Pittsburgh Steelers          16          23
# 6              Detroit Lions   San Francisco 49ers          33          41
# 7   Washington Football Team  Los Angeles Chargers          16          20
# 8          Carolina Panthers         New York Jets          19          14
# 9            Atlanta Falcons   Philadelphia Eagles           6          32
# 10        Kansas City Chiefs      Cleveland Browns          33          29
# 11        New Orleans Saints     Green Bay Packers          38           3
# 12           New York Giants        Denver Broncos          13          27
# 13      New England Patriots        Miami Dolphins          16          17
# 14          Los Angeles Rams         Chicago Bears          34          14
# 15         Las Vegas Raiders      Baltimore Ravens          33          27

# %%
def get_weeks(week_1_games):
    games = dict()
    for i in range(0,len(week_1_games)):
        games[i] = dict()
        games[i]['date'] = week_1_games[i]['scheduled']
        games[i]['game_id'] = week_1_games[i]['id']
        games[i]['home_team'] = week_1_games[i]['home']['name']
        games[i]['away_team'] = week_1_games[i]['away']['name']
        games[i]['home_score'] = week_1_games[i]['scoring']['home_points']
        games[i]['away_score'] = week_1_games[i]['scoring']['away_points'] 
    df = pd.DataFrame.from_dict(games, orient='index')
    return df

# %%
df = pd.DataFrame()
for i in range (0,len(data['weeks'])):
    week_data = data['weeks'][i]['games']
    df_new = get_weeks(week_data)
    df = df.append(df_new)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-2eb3a3cfbeed> in <module>
#       2 for i in range (0,len(data['weeks'])):
#       3     week_data = data['weeks'][i]['games']
# ----> 4     df_new = get_weeks(week_data)
#       5     df = df.append(df_new)
#
# <ipython-input-16-9b965ccee46b> in get_weeks(week_1_games)
#       7         games[i]['home_team'] = week_1_games[i]['home']['name']
#       8         games[i]['away_team'] = week_1_games[i]['away']['name']
# ----> 9         games[i]['home_score'] = week_1_games[i]['scoring']['home_points']
#      10         games[i]['away_score'] = week_1_games[i]['scoring']['away_points']
#      11     df = pd.DataFrame.from_dict(games, orient='index')
#
# KeyError: 'scoring'

# %%
games_df = df.copy()

# %%
WFT_games = games_df[(games_df['home_team'] == 'Washington Football Team') | (games_df['away_team'] == 'Washington Football Team')]

# %%
WFT_games
# Out:
#                         date                               game_id  \
# 7  2021-09-12T17:00:00+00:00  a60b9775-cc49-4a09-9382-31fd6efdf4e7
# 0  2021-09-17T00:20:00+00:00  765bd39d-e8c2-4bc3-9a5d-4d8ece62e953
# 4  2021-09-26T17:00:00+00:00  6d965942-07ce-45c6-bc56-2546123271a6
# 9  2021-10-03T17:00:00+00:00  bed8c1cf-fe14-48c5-8a58-85e06831817d
# 9  2021-10-10T17:00:00+00:00  e67119bb-c4b9-4f40-9d59-8b1b2842eba6
# 3  2021-10-17T17:00:00+00:00  4584877d-5390-4114-b733-2963193a04e6
# 4  2021-10-24T17:00:00+00:00  a0e1205c-8d04-43ce-a56a-ef3d760a0628
#
#                   home_team                 away_team  home_score  away_score
# 7  Washington Football Team      Los Angeles Chargers          16          20
# 0  Washington Football Team           New York Giants          30          29
# 4             Buffalo Bills  Washington Football Team          43          21
# 9           Atlanta Falcons  Washington Football Team          30          34
# 9  Washington Football Team        New Orleans Saints          22          33
# 3  Washington Football Team        Kansas City Chiefs          13          31
# 4         Green Bay Packers  Washington Football Team          24          10

# %%
was_game_ids = list(WFT_games['game_id'])

# %%
was_game_ids
# Out:
# ['a60b9775-cc49-4a09-9382-31fd6efdf4e7',
#  '765bd39d-e8c2-4bc3-9a5d-4d8ece62e953',
#  '6d965942-07ce-45c6-bc56-2546123271a6',
#  'bed8c1cf-fe14-48c5-8a58-85e06831817d',
#  'e67119bb-c4b9-4f40-9d59-8b1b2842eba6',
#  '4584877d-5390-4114-b733-2963193a04e6',
#  'a0e1205c-8d04-43ce-a56a-ef3d760a0628']

# %%
response = requests.get("http://api.sportradar.us/nfl/official/trial/v7/en/games/a60b9775-cc49-4a09-9382-31fd6efdf4e7/pbp.json?api_key=n9yn5ys4mt86x3cfj6t6nxb9")

data = json.loads(response.text)

# %%
data = response.json()

# %%
type(data)
# Out:
# dict

# %%
periods = data['periods']

# %%
events = []
for i in range(0, len(periods)):
    num_events = len(periods[i]['pbp'])
    for j in range(0, num_events):
        events.append((periods[i]['pbp'][j]))

# %%
len(events)
# Out:
# 33

# %%
drives = []
for event in events:
    if event['type'] == 'drive':
        drives.append(event)

# %%
len(drives)
# Out:
# 20

# %%
events_df = pd.DataFrame()
for drive in drives:
    new_df = pd.json_normalize(drive['events'])
    new_df['sequence'] = drive['sequence']
    events_df = events_df.append(new_df)

# %%
clean_df = events_df[['type', 'id', 'sequence', 'clock', 'home_points', 'away_points',
       'play_type', 'description', 'screen_pass', 'hash_mark', 'play_action',
       'run_pass_option', 'statistics', 'details',
       'start_situation.down', 'start_situation.yfd', 'start_situation.possession.alias',
       'start_situation.location.alias',
       'start_situation.location.yardline',
       'end_situation.down', 'end_situation.yfd',
       'end_situation.possession.alias',
       'end_situation.location.alias',
       'end_situation.location.yardline', 'players_rushed', 'men_in_box',
       'blitz', 'play_direction',
       'pocket_location', 'qb_at_snap', 'huddle', 'pass_route', 'running_lane',
       'scoring_play','score.points', 'statistics']]

# %%
clean_df = clean_df.drop('statistics', axis=1)

# %%
clean_df = clean_df.rename(columns={'id': 'play_id'})

# %%
stats_df = pd.DataFrame()
events = []
for drive in drives:
    events.append(drive['events'])

# %%
plays = []
for event in events:
    num_plays = len(event)
    for i in range(0, num_plays):
        plays.append(event[i])

# %%
stats_df = pd.DataFrame()
for play in plays:
    if 'statistics' in play:
        play_df = pd.json_normalize(play['statistics'])
        play_df['play_id'] = play['id']
    stats_df = stats_df.append(play_df)

# %%
stats_df[stats_df['stat_type'] == 'defense'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 2 to 3
# Data columns (total 75 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stat_type            222 non-null    object
#  1   attempt              0 non-null      float64
#  2   yards                0 non-null      float64
#  3   net_yards            0 non-null      float64
#  4   touchback            0 non-null      float64
#  5   onside_attempt       0 non-null      float64
#  6   onside_success       0 non-null      float64
#  7   squib_kick           0 non-null      float64
#  8   player.id            220 non-null    object
#  9   player.name          220 non-null    object
#  10  player.jersey        220 non-null    object
#  11  player.position      220 non-null    object
#  12  player.sr_id         220 non-null    object
#  13  team.id              222 non-null    object
#  14  team.name            222 non-null    object
#  15  team.market          222 non-null    object
#  16  team.alias           222 non-null    object
#  17  team.sr_id           222 non-null    object
#  18  category             161 non-null    object
#  19  play_id              222 non-null    object
#  20  complete             0 non-null      float64
#  21  att_yards            0 non-null      float64
#  22  firstdown            0 non-null      float64
#  23  inside_20            0 non-null      float64
#  24  goaltogo             0 non-null      float64
#  25  blitz                222 non-null    float64
#  26  hurry                222 non-null    float64
#  27  knockdown            222 non-null    float64
#  28  pocket_time          0 non-null      float64
#  29  on_target_throw      0 non-null      float64
#  30  batted_pass          222 non-null    float64
#  31  target               0 non-null      float64
#  32  reception            0 non-null      float64
#  33  yards_after_catch    0 non-null      float64
#  34  dropped              0 non-null      float64
#  35  catchable            0 non-null      float64
#  36  tackle               106 non-null    float64
#  37  missed_tackles       208 non-null    float64
#  38  def_target           222 non-null    float64
#  39  def_comp             222 non-null    float64
#  40  yards_after_contact  0 non-null      float64
#  41  broken_tackles       0 non-null      float64
#  42  kneel_down           0 non-null      float64
#  43  scramble             0 non-null      float64
#  44  ast_tackle           55 non-null     float64
#  45  qb_hit               14 non-null     float64
#  46  tlost                11 non-null     float64
#  47  penalty              0 non-null      float64
#  48  down                 0 non-null      float64
#  49  touchdown            0 non-null      float64
#  50  made                 0 non-null      float64
#  51  return               0 non-null      float64
#  52  incompletion_type    0 non-null      object
#  53  pass_defended        5 non-null      float64
#  54  hang_time            0 non-null      float64
#  55  out_of_bounds        0 non-null      float64
#  56  tlost_yards          12 non-null     float64
#  57  missed               0 non-null      float64
#  58  endzone              0 non-null      float64
#  59  nullified            6 non-null      object
#  60  ast_tlost            3 non-null      float64
#  61  sack                 4 non-null      float64
#  62  sack_yards           4 non-null      float64
#  63  fumble               0 non-null      float64
#  64  forced               0 non-null      float64
#  65  own_rec              0 non-null      float64
#  66  own_rec_yards        0 non-null      float64
#  67  play_category        0 non-null      object
#  68  forced_fumble        4 non-null      float64
#  69  opp_rec              0 non-null      float64
#  70  opp_rec_yards        0 non-null      float64
#  71  lost                 0 non-null      float64
#  72  interception         1 non-null      float64
#  73  int_yards            1 non-null      float64
#  74  faircatch            0 non-null      float64
# dtypes: float64(59), object(16)
# memory usage: 131.8+ KB

# %%
rel_cols = ['stat_type','attempt','complete','yards','att_yards','firstdown','sack','blitz','hurry','knockdown','pocket_time','on_target_throw','batted_pass', 'team.alias', 'sack_yards', 'interception', 'touchdown', 'play_id', 'nullified']

# %%
pass_df = stats_df[stats_df['stat_type'] == 'pass']

# %%
pass_df = pass_df[(rel_cols)]

# %%
pass_df = pass_df.drop_duplicates()

# %%
pass_df['play_id'].value_counts()
# Out:
# ae2c8360-13f9-11ec-96fd-fd610003fee8    1
# dd4dff20-13fe-11ec-b7b0-4158b665dea8    1
# 80ddcbd0-13f4-11ec-96fd-fd610003fee8    1
# 926b04e0-1402-11ec-b7b0-4158b665dea8    1
# ef1898b0-13f3-11ec-96fd-fd610003fee8    1
#                                        ..
# 9bcd6110-13fb-11ec-96fd-fd610003fee8    1
# 6a218660-13f5-11ec-96fd-fd610003fee8    1
# 400cf4c0-13fc-11ec-b7b0-4158b665dea8    1
# 671acfb0-13ed-11ec-96fd-fd610003fee8    1
# c36aca70-13ef-11ec-96fd-fd610003fee8    1
# Name: play_id, Length: 78, dtype: int64

# %%
pass_df = pass_df[pass_df['nullified'] != True]

# %%
pass_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 0
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   stat_type        71 non-null     object
#  1   attempt          68 non-null     float64
#  2   complete         67 non-null     float64
#  3   yards            45 non-null     float64
#  4   att_yards        68 non-null     float64
#  5   firstdown        71 non-null     float64
#  6   sack             3 non-null      float64
#  7   blitz            71 non-null     float64
#  8   hurry            71 non-null     float64
#  9   knockdown        71 non-null     float64
#  10  pocket_time      71 non-null     float64
#  11  on_target_throw  71 non-null     float64
#  12  batted_pass      71 non-null     float64
#  13  team.alias       71 non-null     object
#  14  sack_yards       3 non-null      float64
#  15  interception     1 non-null      float64
#  16  touchdown        2 non-null      float64
#  17  play_id          71 non-null     object
#  18  nullified        0 non-null      object
# dtypes: float64(15), object(4)
# memory usage: 11.1+ KB

# %%
pass_clean_df = clean_df[['play_id', 'sequence', 'description', 'screen_pass', 'hash_mark', 'play_action', 'run_pass_option', 'players_rushed', 'men_in_box', 'pass_route', 'running_lane', 'qb_at_snap', 'start_situation.down', 'start_situation.yfd', 'start_situation.possession.alias']]

# %%
pass_df = pass_df.merge(pass_clean_df, how='inner', on='play_id')

# %%
pass_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 70
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   stat_type                         71 non-null     object
#  1   attempt                           68 non-null     float64
#  2   complete                          67 non-null     float64
#  3   yards                             45 non-null     float64
#  4   att_yards                         68 non-null     float64
#  5   firstdown                         71 non-null     float64
#  6   sack                              3 non-null      float64
#  7   blitz                             71 non-null     float64
#  8   hurry                             71 non-null     float64
#  9   knockdown                         71 non-null     float64
#  10  pocket_time                       71 non-null     float64
#  11  on_target_throw                   71 non-null     float64
#  12  batted_pass                       71 non-null     float64
#  13  team.alias                        71 non-null     object
#  14  sack_yards                        3 non-null      float64
#  15  interception                      1 non-null      float64
#  16  touchdown                         2 non-null      float64
#  17  play_id                           71 non-null     object
#  18  nullified                         0 non-null      object
#  19  sequence                          71 non-null     int64
#  20  description                       71 non-null     object
#  21  screen_pass                       71 non-null     object
#  22  hash_mark                         71 non-null     object
#  23  play_action                       71 non-null     object
#  24  run_pass_option                   71 non-null     object
#  25  players_rushed                    71 non-null     float64
#  26  men_in_box                        71 non-null     float64
#  27  pass_route                        66 non-null     object
#  28  running_lane                      0 non-null      float64
#  29  qb_at_snap                        71 non-null     object
#  30  start_situation.down              71 non-null     float64
#  31  start_situation.yfd               71 non-null     float64
#  32  start_situation.possession.alias  71 non-null     object
# dtypes: float64(20), int64(1), object(12)
# memory usage: 18.9+ KB

# %% [markdown]
# ### Rush Plays

# %%
rush_df = stats_df[stats_df['stat_type'] == 'rush']

# %%
rel_cols = ['stat_type','yards','firstdown', 'yards_after_contact','touchdown', 'play_id', 'nullified']

# %%
rush_df = rush_df[(rel_cols)]

# %%
rush_df = rush_df.drop_duplicates()

# %%
rush_df = rush_df[rush_df['nullified'] != True]

# %%
rush_df
# Out:
#   stat_type  yards  firstdown  yards_after_contact  touchdown  \
# 0      rush   11.0        1.0                  5.0        NaN
# 0      rush   13.0        1.0                  2.0        NaN
# 0      rush    3.0        0.0                  3.0        NaN
# 0      rush    3.0        1.0                  NaN        1.0
# 0      rush    4.0        0.0                  1.0        NaN
# 0      rush    1.0        0.0                  1.0        NaN
# 0      rush    4.0        0.0                  NaN        NaN
# 0      rush   27.0        1.0                 23.0        NaN
# 0      rush   -3.0        0.0                  NaN        NaN
# 0      rush    2.0        0.0                  NaN        NaN
# 0      rush    3.0        0.0                  NaN        NaN
# 0      rush    6.0        1.0                  1.0        NaN
# 0      rush   -1.0        0.0                  NaN        NaN
# 0      rush    7.0        0.0                  1.0        NaN
# 0      rush   -3.0        0.0                  NaN        NaN
# 0      rush    1.0        0.0                  1.0        NaN
# 0      rush    4.0        0.0                  NaN        NaN
# 0      rush    3.0        0.0                  2.0        NaN
# 0      rush    2.0        1.0                  1.0        NaN
# 0      rush    0.0        0.0                  NaN        NaN
# 0      rush    7.0        0.0                  2.0        NaN
# 0      rush    2.0        0.0                  2.0        NaN
# 0      rush    2.0        1.0                  NaN        NaN
# 0      rush    8.0        0.0                  3.0        NaN
# 0      rush    3.0        1.0                  NaN        NaN
# 0      rush    5.0        0.0                  NaN        NaN
# 0      rush    6.0        0.0                  4.0        NaN
# 0      rush    2.0        0.0                  1.0        NaN
# 0      rush    0.0        0.0                  NaN        NaN
# 0      rush   14.0        1.0                 14.0        NaN
# 0      rush    5.0        0.0                  2.0        NaN
# 0      rush    2.0        0.0                  1.0        NaN
# 0      rush    6.0        0.0                  3.0        NaN
# 0      rush    6.0        0.0                  5.0        NaN
# 0      rush    6.0        1.0                  3.0        NaN
# 0      rush    6.0        0.0                  1.0        NaN
# 0      rush    3.0        0.0                  3.0        NaN
# 0      rush    5.0        1.0                  2.0        NaN
# 0      rush   -2.0        0.0                  NaN        NaN
# 0      rush    3.0        0.0                  1.0        NaN
# 0      rush   -1.0        0.0                  NaN        NaN
# 0      rush    0.0        0.0                  NaN        NaN
# 0      rush    6.0        0.0                  1.0        NaN
# 0      rush    4.0        0.0                  2.0        NaN
# 0      rush    5.0        0.0                  NaN        NaN
# 0      rush    2.0        1.0                  NaN        NaN
# 0      rush    5.0        0.0                  1.0        NaN
# 0      rush    9.0        0.0                  3.0        NaN
# 0      rush    4.0        0.0                  2.0        NaN
# 0      rush    1.0        0.0                  1.0        NaN
# 0      rush    2.0        0.0                  NaN        NaN
# 0      rush    9.0        0.0                  3.0        NaN
# 0      rush   -3.0        0.0                  NaN        NaN
# 0      rush   -1.0        0.0                  NaN        NaN
# 0      rush   -1.0        0.0                  NaN        NaN
# 0      rush   -1.0        0.0                  NaN        NaN
#
#                                 play_id nullified
# 0  e4990a80-13eb-11ec-96fd-fd610003fee8       NaN
# 0  1566f000-13ec-11ec-96fd-fd610003fee8       NaN
# 0  3a4f06f0-13ec-11ec-96fd-fd610003fee8       NaN
# 0  9754cf10-13ec-11ec-96fd-fd610003fee8       NaN
# 0  42513d40-13ed-11ec-96fd-fd610003fee8       NaN
# 0  fbae8c20-13ed-11ec-96fd-fd610003fee8       NaN
# 0  a3f4b3f0-13ee-11ec-96fd-fd610003fee8       NaN
# 0  af4aecb0-13ee-11ec-96fd-fd610003fee8       NaN
# 0  cce02ab0-13ee-11ec-96fd-fd610003fee8       NaN
# 0  fe565e20-13ee-11ec-96fd-fd610003fee8       NaN
# 0  792b6a90-13f0-11ec-96fd-fd610003fee8       NaN
# 0  83ab6790-13f0-11ec-96fd-fd610003fee8       NaN
# 0  204372a0-13f1-11ec-96fd-fd610003fee8       NaN
# 0  05e77130-13f2-11ec-96fd-fd610003fee8       NaN
# 0  2b1dcf30-13f2-11ec-96fd-fd610003fee8       NaN
# 0  a1c7ec10-13f2-11ec-96fd-fd610003fee8       NaN
# 0  60741110-13f4-11ec-96fd-fd610003fee8       NaN
# 0  9eb47fa0-13f4-11ec-96fd-fd610003fee8       NaN
# 0  d0f4e0e0-13f4-11ec-96fd-fd610003fee8       NaN
# 0  576c66c0-13f5-11ec-96fd-fd610003fee8       NaN
# 0  adc225a0-13f5-11ec-96fd-fd610003fee8       NaN
# 0  16101cc0-13f6-11ec-96fd-fd610003fee8       NaN
# 0  340f4020-13f6-11ec-96fd-fd610003fee8       NaN
# 0  f9c4a760-13f6-11ec-96fd-fd610003fee8       NaN
# 0  6925fd70-13f7-11ec-96fd-fd610003fee8       NaN
# 0  9c911120-13f9-11ec-96fd-fd610003fee8       NaN
# 0  c6a80f90-13f9-11ec-96fd-fd610003fee8       NaN
# 0  14476de0-13fa-11ec-96fd-fd610003fee8       NaN
# 0  ec906300-13fa-11ec-96fd-fd610003fee8       NaN
# 0  8717b680-13fb-11ec-96fd-fd610003fee8       NaN
# 0  b20a6ef0-13fb-11ec-96fd-fd610003fee8       NaN
# 0  e4677ff0-13fb-11ec-96fd-fd610003fee8       NaN
# 0  7b7b0970-13fc-11ec-b7b0-4158b665dea8       NaN
# 0  ab732860-13fc-11ec-b7b0-4158b665dea8       NaN
# 0  bfa7e320-13fc-11ec-b7b0-4158b665dea8       NaN
# 0  df254210-13fc-11ec-b7b0-4158b665dea8       NaN
# 0  f44176a0-13fc-11ec-b7b0-4158b665dea8       NaN
# 0  07b37da0-13fd-11ec-b7b0-4158b665dea8       NaN
# 0  07370530-13fe-11ec-b7b0-4158b665dea8       NaN
# 0  c347db50-13fe-11ec-b7b0-4158b665dea8       NaN
# 0  5706bb90-13ff-11ec-b7b0-4158b665dea8       NaN
# 0  8eaa33b0-13ff-11ec-b7b0-4158b665dea8       NaN
# 0  6bfc86f0-1400-11ec-b7b0-4158b665dea8       NaN
# 0  a7132cd0-1400-11ec-b7b0-4158b665dea8       NaN
# 0  c2e1dba0-1400-11ec-b7b0-4158b665dea8       NaN
# 0  1185d8b0-1401-11ec-b7b0-4158b665dea8       NaN
# 0  19c35fc0-1401-11ec-b7b0-4158b665dea8       NaN
# 0  64e206a0-1401-11ec-b7b0-4158b665dea8       NaN
# 0  22c2e1d0-1402-11ec-b7b0-4158b665dea8       NaN
# 0  c7e6e210-1402-11ec-b7b0-4158b665dea8       NaN
# 0  de52ef30-1402-11ec-b7b0-4158b665dea8       NaN
# 0  6a221a40-1403-11ec-b7b0-4158b665dea8       NaN
# 0  8abf6820-1403-11ec-b7b0-4158b665dea8       NaN
# 0  c42ca3c0-1403-11ec-b7b0-4158b665dea8       NaN
# 0  d6f17ad0-1403-11ec-b7b0-4158b665dea8       NaN
# 0  eea4adf0-1403-11ec-b7b0-4158b665dea8       NaN

# %%
rush_clean_df = clean_df[['play_id', 'sequence', 'description', 'run_pass_option', 'players_rushed', 'men_in_box', 'running_lane', 'qb_at_snap', 'start_situation.down', 'start_situation.yfd', 'start_situation.possession.alias']]

# %%
rush_df = rush_df.merge(rush_clean_df, how='inner', on='play_id')

# %%
len(rush_df)
# Out:
# 56

# %% [markdown]
# #### Penalties

# %%
penalty_df = stats_df[stats_df['stat_type'] == 'penalty']

# %%
rel_cols = ['stat_type', 'yards', 'player.name', 'play_id', 'team.alias']

# %%
penalty_df = penalty_df[(rel_cols)]

# %%
penalty_df
# Out:
#   stat_type  yards           player.name  \
# 0   penalty    5.0  James Smith-Williams
# 2   penalty   35.0     Asante Samuel Jr.
# 1   penalty    9.0         Mark Webb Jr.
# 0   penalty    5.0           Chase Young
# 2   penalty    2.0   William Jackson III
# 2   penalty   10.0          Bryan Bulaga
# 2   penalty   15.0             Joey Bosa
# 1   penalty   10.0       Brandon Scherff
# 0   penalty    5.0       Brandon Scherff
# 2   penalty   15.0             Joey Bosa
# 2   penalty   15.0        Adam Humphries
# 0   penalty    5.0             Troy Apke
# 1   penalty   10.0     Camaron Cheeseman
# 2   penalty   10.0          Oday Aboushi
#
#                                 play_id team.alias
# 0  71e20450-13ec-11ec-96fd-fd610003fee8        WAS
# 2  b45c7640-13f0-11ec-96fd-fd610003fee8        LAC
# 1  9d384740-13f1-11ec-96fd-fd610003fee8        LAC
# 0  839e5d50-13f2-11ec-96fd-fd610003fee8        WAS
# 2  80ddcbd0-13f4-11ec-96fd-fd610003fee8        WAS
# 2  fe89bb70-13f4-11ec-96fd-fd610003fee8        LAC
# 2  154f4850-13f7-11ec-96fd-fd610003fee8        LAC
# 1  10c321c0-13fd-11ec-b7b0-4158b665dea8        WAS
# 0  244befa0-13fe-11ec-b7b0-4158b665dea8        WAS
# 2  8d2db060-1400-11ec-b7b0-4158b665dea8        LAC
# 2  279e2080-1401-11ec-b7b0-4158b665dea8        WAS
# 0  755636f0-1401-11ec-b7b0-4158b665dea8        WAS
# 1  9a1b5c90-1401-11ec-b7b0-4158b665dea8        WAS
# 2  3f51d360-1402-11ec-b7b0-4158b665dea8        LAC

# %%
penalty_clean_df = clean_df[['play_id', 'sequence', 'description','start_situation.down', 'start_situation.yfd', 'start_situation.possession.alias', 'end_situation.down']]

# %%
penalty_df = penalty_df.merge(penalty_clean_df, how='inner', on='play_id')

# %%
penalty_df
# Out:
#    stat_type  yards           player.name  \
# 0    penalty    5.0  James Smith-Williams
# 1    penalty   35.0     Asante Samuel Jr.
# 2    penalty    9.0         Mark Webb Jr.
# 3    penalty    5.0           Chase Young
# 4    penalty    2.0   William Jackson III
# 5    penalty   10.0          Bryan Bulaga
# 6    penalty   15.0             Joey Bosa
# 7    penalty   10.0       Brandon Scherff
# 8    penalty    5.0       Brandon Scherff
# 9    penalty   15.0             Joey Bosa
# 10   penalty   15.0        Adam Humphries
# 11   penalty    5.0             Troy Apke
# 12   penalty   10.0     Camaron Cheeseman
# 13   penalty   10.0          Oday Aboushi
#
#                                  play_id team.alias  sequence  \
# 0   71e20450-13ec-11ec-96fd-fd610003fee8        WAS         1
# 1   b45c7640-13f0-11ec-96fd-fd610003fee8        LAC         6
# 2   9d384740-13f1-11ec-96fd-fd610003fee8        LAC         7
# 3   839e5d50-13f2-11ec-96fd-fd610003fee8        WAS         7
# 4   80ddcbd0-13f4-11ec-96fd-fd610003fee8        WAS         9
# 5   fe89bb70-13f4-11ec-96fd-fd610003fee8        LAC         9
# 6   154f4850-13f7-11ec-96fd-fd610003fee8        LAC        10
# 7   10c321c0-13fd-11ec-b7b0-4158b665dea8        WAS        13
# 8   244befa0-13fe-11ec-b7b0-4158b665dea8        WAS        13
# 9   8d2db060-1400-11ec-b7b0-4158b665dea8        LAC        17
# 10  279e2080-1401-11ec-b7b0-4158b665dea8        WAS        17
# 11  755636f0-1401-11ec-b7b0-4158b665dea8        WAS        17
# 12  9a1b5c90-1401-11ec-b7b0-4158b665dea8        WAS        17
# 13  3f51d360-1402-11ec-b7b0-4158b665dea8        LAC        18
#
#                                           description  start_situation.down  \
# 0   PENALTY on WAS-J.Smith-Williams, Neutral Zone ...                   3.0
# 1   R.Fitzpatrick steps back to pass. R.Fitzpatric...                   1.0
# 2   D.Hopkins kicks 63 yards from WAS 35 to the LA...                   0.0
# 3   PENALTY on WAS-C.Young, Defensive Offside, 5 y...                   2.0
# 4   J.Herbert pass short left complete to LAC 31. ...                   3.0
# 5   J.Herbert pass short middle complete to LAC 44...                   2.0
# 6   T.Heinicke steps back to pass. T.Heinicke pass...                   2.0
# 7   J.Patterson rushed to LAC 25 for yards. Pushed...                   1.0
# 8   PENALTY on WAS-B.Scherff, False Start, 5 yards...                   3.0
# 9   T.Heinicke steps back to pass. T.Heinicke pass...                   3.0
# 10  T.Heinicke pass complete to LAC 38. Catch made...                   2.0
# 11  PENALTY on WAS-T.Apke, False Start, 5 yards, a...                   4.0
# 12  T.Way punts 37 yards to LAC 8, Center-C.Cheese...                   4.0
# 13  J.Herbert pass complete to LAC 22. Catch made ...                   2.0
#
#     start_situation.yfd start_situation.possession.alias  end_situation.down
# 0                  10.0                              LAC                 3.0
# 1                  10.0                              WAS                 1.0
# 2                   0.0                              WAS                 1.0
# 3                  10.0                              LAC                 2.0
# 4                   5.0                              LAC                 1.0
# 5                  10.0                              LAC                 2.0
# 6                   2.0                              WAS                 1.0
# 7                  10.0                              WAS                 1.0
# 8                   5.0                              WAS                 3.0
# 9                   4.0                              WAS                 1.0
# 10                  5.0                              WAS                 2.0
# 11                  7.0                              WAS                 4.0
# 12                 12.0                              WAS                 1.0
# 13                  6.0                              LAC                 2.0

# %%
from data_cleaning import return_pass_df, return_rush_df, return_penalty_df

# %%
return_pass_df(data)
# Out:
#    stat_type  attempt  complete  yards  att_yards  firstdown  sack  blitz  \
# 0       pass      1.0       1.0   10.0       -4.0        1.0   NaN    0.0
# 1       pass      1.0       1.0    6.0        5.0        0.0   NaN    1.0
# 2       pass      1.0       1.0    9.0        5.0        0.0   NaN    0.0
# 3       pass      1.0       1.0   11.0       10.0        1.0   NaN    0.0
# 4       pass      1.0       1.0   -3.0       -3.0        0.0   NaN    0.0
# ..       ...      ...       ...    ...        ...        ...   ...    ...
# 66      pass      1.0       0.0    NaN       -4.0        0.0   NaN    0.0
# 67      pass      1.0       1.0    7.0        3.0        0.0   NaN    1.0
# 68      pass      1.0       1.0   19.0       12.0        1.0   NaN    0.0
# 69      pass      1.0       1.0   20.0       20.0        1.0   NaN    1.0
# 70      pass      1.0       1.0    9.0        6.0        1.0   NaN    0.0
#
#     hurry  knockdown  ...  play_action  run_pass_option  players_rushed  \
# 0     0.0        0.0  ...         True            False             4.0
# 1     0.0        0.0  ...        False            False             5.0
# 2     0.0        0.0  ...         True            False             3.0
# 3     0.0        0.0  ...        False            False             4.0
# 4     0.0        0.0  ...         True            False             4.0
# ..    ...        ...  ...          ...              ...             ...
# 66    0.0        0.0  ...         True            False             4.0
# 67    0.0        0.0  ...        False            False             4.0
# 68    0.0        0.0  ...        False            False             4.0
# 69    0.0        0.0  ...        False            False             5.0
# 70    0.0        0.0  ...        False            False             4.0
#
#    men_in_box  pass_route  running_lane    qb_at_snap start_situation.down  \
# 0         6.0        Flat           NaN       Shotgun                  1.0
# 1         6.0         Out           NaN       Shotgun                  1.0
# 2         6.0         Out           NaN       Shotgun                  1.0
# 3         7.0        Curl           NaN        Pistol                  1.0
# 4         7.0       Slant           NaN  Under Center                  2.0
# ..        ...         ...           ...           ...                  ...
# 66        8.0        Flat           NaN  Under Center                  1.0
# 67        6.0         Out           NaN       Shotgun                  2.0
# 68        6.0          In           NaN       Shotgun                  3.0
# 69        6.0          Go           NaN       Shotgun                  3.0
# 70        5.0        Curl           NaN       Shotgun                  3.0
#
#    start_situation.yfd  start_situation.possession.alias
# 0                 10.0                               LAC
# 1                 10.0                               LAC
# 2                 10.0                               LAC
# 3                 10.0                               LAC
# 4                  7.0                               LAC
# ..                 ...                               ...
# 66                10.0                               LAC
# 67                10.0                               LAC
# 68                 3.0                               LAC
# 69                 7.0                               LAC
# 70                 4.0                               LAC
#
# [71 rows x 33 columns]

# %%
return_rush_df(data)
# Out:
#    stat_type  yards  firstdown  yards_after_contact  touchdown  \
# 0       rush   11.0        1.0                  5.0        NaN
# 1       rush   13.0        1.0                  2.0        NaN
# 2       rush    3.0        0.0                  3.0        NaN
# 3       rush    3.0        1.0                  NaN        1.0
# 4       rush    4.0        0.0                  1.0        NaN
# 5       rush    1.0        0.0                  1.0        NaN
# 6       rush    4.0        0.0                  NaN        NaN
# 7       rush   27.0        1.0                 23.0        NaN
# 8       rush   -3.0        0.0                  NaN        NaN
# 9       rush    2.0        0.0                  NaN        NaN
# 10      rush    3.0        0.0                  NaN        NaN
# 11      rush    6.0        1.0                  1.0        NaN
# 12      rush   -1.0        0.0                  NaN        NaN
# 13      rush    7.0        0.0                  1.0        NaN
# 14      rush   -3.0        0.0                  NaN        NaN
# 15      rush    1.0        0.0                  1.0        NaN
# 16      rush    4.0        0.0                  NaN        NaN
# 17      rush    3.0        0.0                  2.0        NaN
# 18      rush    2.0        1.0                  1.0        NaN
# 19      rush    0.0        0.0                  NaN        NaN
# 20      rush    7.0        0.0                  2.0        NaN
# 21      rush    2.0        0.0                  2.0        NaN
# 22      rush    2.0        1.0                  NaN        NaN
# 23      rush    8.0        0.0                  3.0        NaN
# 24      rush    3.0        1.0                  NaN        NaN
# 25      rush    5.0        0.0                  NaN        NaN
# 26      rush    6.0        0.0                  4.0        NaN
# 27      rush    2.0        0.0                  1.0        NaN
# 28      rush    0.0        0.0                  NaN        NaN
# 29      rush   14.0        1.0                 14.0        NaN
# 30      rush    5.0        0.0                  2.0        NaN
# 31      rush    2.0        0.0                  1.0        NaN
# 32      rush    6.0        0.0                  3.0        NaN
# 33      rush    6.0        0.0                  5.0        NaN
# 34      rush    6.0        1.0                  3.0        NaN
# 35      rush    6.0        0.0                  1.0        NaN
# 36      rush    3.0        0.0                  3.0        NaN
# 37      rush    5.0        1.0                  2.0        NaN
# 38      rush   -2.0        0.0                  NaN        NaN
# 39      rush    3.0        0.0                  1.0        NaN
# 40      rush   -1.0        0.0                  NaN        NaN
# 41      rush    0.0        0.0                  NaN        NaN
# 42      rush    6.0        0.0                  1.0        NaN
# 43      rush    4.0        0.0                  2.0        NaN
# 44      rush    5.0        0.0                  NaN        NaN
# 45      rush    2.0        1.0                  NaN        NaN
# 46      rush    5.0        0.0                  1.0        NaN
# 47      rush    9.0        0.0                  3.0        NaN
# 48      rush    4.0        0.0                  2.0        NaN
# 49      rush    1.0        0.0                  1.0        NaN
# 50      rush    2.0        0.0                  NaN        NaN
# 51      rush    9.0        0.0                  3.0        NaN
# 52      rush   -3.0        0.0                  NaN        NaN
# 53      rush   -1.0        0.0                  NaN        NaN
# 54      rush   -1.0        0.0                  NaN        NaN
# 55      rush   -1.0        0.0                  NaN        NaN
#
#                                  play_id nullified  sequence  \
# 0   e4990a80-13eb-11ec-96fd-fd610003fee8       NaN         1
# 1   1566f000-13ec-11ec-96fd-fd610003fee8       NaN         1
# 2   3a4f06f0-13ec-11ec-96fd-fd610003fee8       NaN         1
# 3   9754cf10-13ec-11ec-96fd-fd610003fee8       NaN         1
# 4   42513d40-13ed-11ec-96fd-fd610003fee8       NaN         2
# 5   fbae8c20-13ed-11ec-96fd-fd610003fee8       NaN         3
# 6   a3f4b3f0-13ee-11ec-96fd-fd610003fee8       NaN         4
# 7   af4aecb0-13ee-11ec-96fd-fd610003fee8       NaN         4
# 8   cce02ab0-13ee-11ec-96fd-fd610003fee8       NaN         4
# 9   fe565e20-13ee-11ec-96fd-fd610003fee8       NaN         4
# 10  792b6a90-13f0-11ec-96fd-fd610003fee8       NaN         6
# 11  83ab6790-13f0-11ec-96fd-fd610003fee8       NaN         6
# 12  204372a0-13f1-11ec-96fd-fd610003fee8       NaN         6
# 13  05e77130-13f2-11ec-96fd-fd610003fee8       NaN         7
# 14  2b1dcf30-13f2-11ec-96fd-fd610003fee8       NaN         7
# 15  a1c7ec10-13f2-11ec-96fd-fd610003fee8       NaN         7
# 16  60741110-13f4-11ec-96fd-fd610003fee8       NaN         9
# 17  9eb47fa0-13f4-11ec-96fd-fd610003fee8       NaN         9
# 18  d0f4e0e0-13f4-11ec-96fd-fd610003fee8       NaN         9
# 19  576c66c0-13f5-11ec-96fd-fd610003fee8       NaN         9
# 20  adc225a0-13f5-11ec-96fd-fd610003fee8       NaN         9
# 21  16101cc0-13f6-11ec-96fd-fd610003fee8       NaN         9
# 22  340f4020-13f6-11ec-96fd-fd610003fee8       NaN         9
# 23  f9c4a760-13f6-11ec-96fd-fd610003fee8       NaN        10
# 24  6925fd70-13f7-11ec-96fd-fd610003fee8       NaN        10
# 25  9c911120-13f9-11ec-96fd-fd610003fee8       NaN        11
# 26  c6a80f90-13f9-11ec-96fd-fd610003fee8       NaN        11
# 27  14476de0-13fa-11ec-96fd-fd610003fee8       NaN        11
# 28  ec906300-13fa-11ec-96fd-fd610003fee8       NaN        12
# 29  8717b680-13fb-11ec-96fd-fd610003fee8       NaN        12
# 30  b20a6ef0-13fb-11ec-96fd-fd610003fee8       NaN        12
# 31  e4677ff0-13fb-11ec-96fd-fd610003fee8       NaN        12
# 32  7b7b0970-13fc-11ec-b7b0-4158b665dea8       NaN        13
# 33  ab732860-13fc-11ec-b7b0-4158b665dea8       NaN        13
# 34  bfa7e320-13fc-11ec-b7b0-4158b665dea8       NaN        13
# 35  df254210-13fc-11ec-b7b0-4158b665dea8       NaN        13
# 36  f44176a0-13fc-11ec-b7b0-4158b665dea8       NaN        13
# 37  07b37da0-13fd-11ec-b7b0-4158b665dea8       NaN        13
# 38  07370530-13fe-11ec-b7b0-4158b665dea8       NaN        13
# 39  c347db50-13fe-11ec-b7b0-4158b665dea8       NaN        14
# 40  5706bb90-13ff-11ec-b7b0-4158b665dea8       NaN        15
# 41  8eaa33b0-13ff-11ec-b7b0-4158b665dea8       NaN        16
# 42  6bfc86f0-1400-11ec-b7b0-4158b665dea8       NaN        17
# 43  a7132cd0-1400-11ec-b7b0-4158b665dea8       NaN        17
# 44  c2e1dba0-1400-11ec-b7b0-4158b665dea8       NaN        17
# 45  1185d8b0-1401-11ec-b7b0-4158b665dea8       NaN        17
# 46  19c35fc0-1401-11ec-b7b0-4158b665dea8       NaN        17
# 47  64e206a0-1401-11ec-b7b0-4158b665dea8       NaN        17
# 48  22c2e1d0-1402-11ec-b7b0-4158b665dea8       NaN        18
# 49  c7e6e210-1402-11ec-b7b0-4158b665dea8       NaN        18
# 50  de52ef30-1402-11ec-b7b0-4158b665dea8       NaN        18
# 51  6a221a40-1403-11ec-b7b0-4158b665dea8       NaN        18
# 52  8abf6820-1403-11ec-b7b0-4158b665dea8       NaN        18
# 53  c42ca3c0-1403-11ec-b7b0-4158b665dea8       NaN        18
# 54  d6f17ad0-1403-11ec-b7b0-4158b665dea8       NaN        18
# 55  eea4adf0-1403-11ec-b7b0-4158b665dea8       NaN        18
#
#                                           description run_pass_option  \
# 0   A.Ekeler rushed left tackle to WAS 48 for 11 y...           False
# 1   L.Rountree rushed to WAS 26 for 13 yards. Tack...           False
# 2   L.Rountree rushed to WAS 12 for 3 yards. Pushe...           False
# 3   A.Ekeler rushed left tackle to WAS End Zone fo...           False
# 4   A.Gibson rushed left guard to WAS 30 for 4 yar...           False
# 5   A.Ekeler rushed left tackle to LAC 13 for 1 ya...           False
# 6   A.Gibson rushed right guard to LAC 44 for 4 ya...           False
# 7   A.Gibson rushed left guard to LAC 17 for 27 ya...           False
# 8   A.Gibson rushed left tackle to LAC 20 for -3 y...           False
# 9   R.Fitzpatrick scrambles up the middle to LAC 1...           False
# 10  A.Gibson rushed right guard to WAS 37 for 3 ya...           False
# 11  A.Gibson rushed left guard to WAS 43 for 6 yar...           False
# 12  A.Gibson rushed right tackle to LAC 23 for -1 ...           False
# 13  L.Rountree rushed right end to LAC 34 for 7 ya...           False
# 14  L.Rountree rushed up the middle to LAC 47 for ...           False
# 15  A.Ekeler rushed right end to WAS 15 for 1 yard...           False
# 16  A.Ekeler rushed right guard to LAC 30 for 4 ya...           False
# 17  L.Rountree rushed left tackle to LAC 36 for 3 ...           False
# 18  G.Nabers rushed right guard to LAC 44 for 2 ya...           False
# 19  L.Rountree rushed right end to WAS 45 for 0 ya...           False
# 20  A.Ekeler rushed left end to WAS 10 for 7 yards...           False
# 21  A.Ekeler rushed left end to WAS 8 for 2 yards....           False
# 22  J.Herbert rushed left guard to WAS 6 for 2 yar...           False
# 23  J.McKissic rushed left guard to WAS 33 for 8 y...           False
# 24  T.Heinicke scrambles to LAC 30 for 3 yards. Pu...           False
# 25  T.Heinicke scrambles to WAS 24 for 5 yards. Pu...           False
# 26  A.Gibson rushed to WAS 41 for 6 yards. Tackled...           False
# 27  A.Gibson rushed left end to LAC 46 for 2 yards...           False
# 28  A.Ekeler rushed to LAC 25 for 0 yards. Tackled...           False
# 29  A.Ekeler rushed to WAS 20 for 14 yards. Tackle...           False
# 30  J.Jackson rushed to WAS 15 for 5 yards. Tackle...           False
# 31  A.Ekeler rushed to WAS 7 for 2 yards. Tackled ...           False
# 32  A.Gibson rushed to WAS 26 for 6 yards. Pushed ...           False
# 33  A.Gibson rushed to WAS 49 for 6 yards. Tackled...           False
# 34  A.Gibson rushed to LAC 45 for 6 yards. Tackled...           False
# 35  A.Gibson rushed to LAC 39 for 6 yards. Tackled...           False
# 36  A.Gibson rushed to LAC 36 for 3 yards. Tackled...           False
# 37  A.Gibson rushed to LAC 31 for 5 yards. Tackled...           False
# 38  A.Gibson rushed to LAC 26 for -2 yards. Tackle...           False
# 39  L.Rountree rushed to WAS 37 for 3 yards. Tackl...           False
# 40  A.Gibson rushed to WAS 3 for -1 yards. A.Gibso...           False
# 41  A.Ekeler rushed to WAS 3 for 0 yards. Tackled ...           False
# 42  A.Gibson rushed to WAS 31 for 6 yards. Tackled...           False
# 43  J.Patterson rushed to WAS 50 for 4 yards. Tack...           False
# 44  J.Patterson rushed to LAC 45 for 5 yards. Tack...           False
# 45  A.Gibson rushed to LAC 43 for 2 yards. Tackled...           False
# 46  A.Gibson rushed to LAC 38 for 5 yards. Tackled...           False
# 47  T.Heinicke scrambles to LAC 40 for 9 yards. Ta...           False
# 48  A.Ekeler rushed to LAC 22 for 4 yards. Tackled...           False
# 49  L.Rountree rushed to WAS 44 for 1 yards. Tackl...           False
# 50  A.Ekeler rushed to WAS 42 for 2 yards. Tackled...           False
# 51  A.Ekeler rushed to WAS 13 for 9 yards. Tackled...           False
# 52  A.Ekeler rushed to WAS 16 for -3 yards. Tackle...           False
# 53                     J.Herbert kneels at the WAS 8.           False
# 54                     J.Herbert kneels at the WAS 9.           False
# 55                    J.Herbert kneels at the WAS 10.           False
#
#     players_rushed  men_in_box  running_lane    qb_at_snap  \
# 0              NaN         8.0           5.0       Shotgun
# 1              NaN         8.0           5.0  Under Center
# 2              NaN         6.0           6.0       Shotgun
# 3              NaN         6.0           3.0       Shotgun
# 4              NaN         6.0           2.0       Shotgun
# 5              NaN         8.0           1.0  Under Center
# 6              NaN         6.0           6.0  Under Center
# 7              NaN         6.0           2.0       Shotgun
# 8              NaN         6.0           3.0       Shotgun
# 9              NaN         4.0           NaN       Shotgun
# 10             NaN         6.0           1.0       Shotgun
# 11             NaN         6.0           2.0       Shotgun
# 12             NaN         7.0           8.0  Under Center
# 13             NaN         7.0           2.0  Under Center
# 14             NaN         6.0           1.0       Shotgun
# 15             NaN         7.0           4.0  Under Center
# 16             NaN         8.0           1.0  Under Center
# 17             NaN         6.0           5.0       Shotgun
# 18             NaN         9.0           1.0  Under Center
# 19             NaN         6.0           4.0       Shotgun
# 20             NaN         8.0           5.0  Under Center
# 21             NaN         6.0           5.0  Under Center
# 22             NaN         7.0           1.0  Under Center
# 23             NaN         6.0           2.0       Shotgun
# 24             NaN         5.0           NaN       Shotgun
# 25             NaN         6.0           NaN  Under Center
# 26             NaN         7.0           5.0       Shotgun
# 27             NaN         6.0           5.0       Shotgun
# 28             NaN         7.0           7.0  Under Center
# 29             NaN         8.0           4.0  Under Center
# 30             NaN         5.0           5.0       Shotgun
# 31             NaN         7.0           3.0       Shotgun
# 32             NaN         6.0           3.0  Under Center
# 33             NaN         6.0           6.0  Under Center
# 34             NaN         6.0           7.0       Shotgun
# 35             NaN         7.0           2.0       Shotgun
# 36             NaN         6.0           2.0       Shotgun
# 37             NaN         7.0           2.0       Shotgun
# 38             NaN         7.0           5.0       Shotgun
# 39             NaN         6.0           1.0  Under Center
# 40             NaN         7.0           8.0  Under Center
# 41             NaN         7.0           1.0  Under Center
# 42             NaN         5.0           1.0       Shotgun
# 43             NaN         6.0           1.0       Shotgun
# 44             NaN         5.0           2.0       Shotgun
# 45             NaN         8.0           5.0       Shotgun
# 46             NaN         6.0           5.0       Shotgun
# 47             NaN         6.0           NaN       Shotgun
# 48             NaN         7.0           3.0  Under Center
# 49             NaN         7.0           8.0  Under Center
# 50             NaN         9.0           2.0  Under Center
# 51             NaN         8.0           4.0  Under Center
# 52             NaN         7.0           2.0  Under Center
# 53             NaN         NaN           NaN  Under Center
# 54             NaN         NaN           NaN  Under Center
# 55             NaN         NaN           NaN  Under Center
#
#     start_situation.down  start_situation.yfd start_situation.possession.alias
# 0                    2.0                  4.0                              LAC
# 1                    2.0                  1.0                              LAC
# 2                    1.0                 10.0                              LAC
# 3                    1.0                  3.0                              LAC
# 4                    1.0                 10.0                              WAS
# 5                    2.0                 10.0                              LAC
# 6                    1.0                 10.0                              WAS
# 7                    2.0                  7.0                              WAS
# 8                    1.0                 10.0                              WAS
# 9                    3.0                  7.0                              WAS
# 10                   2.0                  5.0                              WAS
# 11                   3.0                  2.0                              WAS
# 12                   1.0                 10.0                              WAS
# 13                   1.0                 10.0                              LAC
# 14                   1.0                 10.0                              LAC
# 15                   2.0                  5.0                              LAC
# 16                   1.0                 10.0                              LAC
# 17                   1.0                 10.0                              LAC
# 18                   3.0                  1.0                              LAC
# 19                   1.0                 10.0                              LAC
# 20                   1.0                 10.0                              LAC
# 21                   2.0                  3.0                              LAC
# 22                   3.0                  1.0                              LAC
# 23                   1.0                 10.0                              WAS
# 24                   2.0                  3.0                              WAS
# 25                   1.0                 10.0                              WAS
# 26                   1.0                 10.0                              WAS
# 27                   2.0                  8.0                              WAS
# 28                   1.0                 10.0                              LAC
# 29                   1.0                 10.0                              LAC
# 30                   2.0                 10.0                              LAC
# 31                   1.0                  9.0                              LAC
# 32                   1.0                 10.0                              WAS
# 33                   1.0                 10.0                              WAS
# 34                   2.0                  4.0                              WAS
# 35                   2.0                 10.0                              WAS
# 36                   3.0                  4.0                              WAS
# 37                   4.0                  1.0                              WAS
# 38                   2.0                  2.0                              WAS
# 39                   1.0                 10.0                              LAC
# 40                   1.0                 10.0                              WAS
# 41                   1.0                  4.0                              LAC
# 42                   2.0                 10.0                              WAS
# 43                   1.0                 10.0                              WAS
# 44                   2.0                  6.0                              WAS
# 45                   3.0                  1.0                              WAS
# 46                   1.0                 10.0                              WAS
# 47                   3.0                 16.0                              WAS
# 48                   1.0                 10.0                              LAC
# 49                   1.0                 10.0                              LAC
# 50                   2.0                  9.0                              LAC
# 51                   1.0                 10.0                              LAC
# 52                   2.0                  1.0                              LAC
# 53                   1.0                  7.0                              LAC
# 54                   2.0                  8.0                              LAC
# 55                   3.0                  9.0                              LAC

# %%
return_penalty_df(data)
# Out:
#    stat_type  yards           player.name  \
# 0    penalty    5.0  James Smith-Williams
# 1    penalty   35.0     Asante Samuel Jr.
# 2    penalty    9.0         Mark Webb Jr.
# 3    penalty    5.0           Chase Young
# 4    penalty    2.0   William Jackson III
# 5    penalty   10.0          Bryan Bulaga
# 6    penalty   15.0             Joey Bosa
# 7    penalty   10.0       Brandon Scherff
# 8    penalty    5.0       Brandon Scherff
# 9    penalty   15.0             Joey Bosa
# 10   penalty   15.0        Adam Humphries
# 11   penalty    5.0             Troy Apke
# 12   penalty   10.0     Camaron Cheeseman
# 13   penalty   10.0          Oday Aboushi
#
#                                  play_id team.alias  sequence  \
# 0   71e20450-13ec-11ec-96fd-fd610003fee8        WAS         1
# 1   b45c7640-13f0-11ec-96fd-fd610003fee8        LAC         6
# 2   9d384740-13f1-11ec-96fd-fd610003fee8        LAC         7
# 3   839e5d50-13f2-11ec-96fd-fd610003fee8        WAS         7
# 4   80ddcbd0-13f4-11ec-96fd-fd610003fee8        WAS         9
# 5   fe89bb70-13f4-11ec-96fd-fd610003fee8        LAC         9
# 6   154f4850-13f7-11ec-96fd-fd610003fee8        LAC        10
# 7   10c321c0-13fd-11ec-b7b0-4158b665dea8        WAS        13
# 8   244befa0-13fe-11ec-b7b0-4158b665dea8        WAS        13
# 9   8d2db060-1400-11ec-b7b0-4158b665dea8        LAC        17
# 10  279e2080-1401-11ec-b7b0-4158b665dea8        WAS        17
# 11  755636f0-1401-11ec-b7b0-4158b665dea8        WAS        17
# 12  9a1b5c90-1401-11ec-b7b0-4158b665dea8        WAS        17
# 13  3f51d360-1402-11ec-b7b0-4158b665dea8        LAC        18
#
#                                           description  start_situation.down  \
# 0   PENALTY on WAS-J.Smith-Williams, Neutral Zone ...                   3.0
# 1   R.Fitzpatrick steps back to pass. R.Fitzpatric...                   1.0
# 2   D.Hopkins kicks 63 yards from WAS 35 to the LA...                   0.0
# 3   PENALTY on WAS-C.Young, Defensive Offside, 5 y...                   2.0
# 4   J.Herbert pass short left complete to LAC 31. ...                   3.0
# 5   J.Herbert pass short middle complete to LAC 44...                   2.0
# 6   T.Heinicke steps back to pass. T.Heinicke pass...                   2.0
# 7   J.Patterson rushed to LAC 25 for yards. Pushed...                   1.0
# 8   PENALTY on WAS-B.Scherff, False Start, 5 yards...                   3.0
# 9   T.Heinicke steps back to pass. T.Heinicke pass...                   3.0
# 10  T.Heinicke pass complete to LAC 38. Catch made...                   2.0
# 11  PENALTY on WAS-T.Apke, False Start, 5 yards, a...                   4.0
# 12  T.Way punts 37 yards to LAC 8, Center-C.Cheese...                   4.0
# 13  J.Herbert pass complete to LAC 22. Catch made ...                   2.0
#
#     start_situation.yfd start_situation.possession.alias  end_situation.down
# 0                  10.0                              LAC                 3.0
# 1                  10.0                              WAS                 1.0
# 2                   0.0                              WAS                 1.0
# 3                  10.0                              LAC                 2.0
# 4                   5.0                              LAC                 1.0
# 5                  10.0                              LAC                 2.0
# 6                   2.0                              WAS                 1.0
# 7                  10.0                              WAS                 1.0
# 8                   5.0                              WAS                 3.0
# 9                   4.0                              WAS                 1.0
# 10                  5.0                              WAS                 2.0
# 11                  7.0                              WAS                 4.0
# 12                 12.0                              WAS                 1.0
# 13                  6.0                              LAC                 2.0

# %% [markdown]
# #### Defense

# %%
def_stats_df = stats_df[stats_df['stat_type'] == 'defense']

# %%
def_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 2 to 3
# Data columns (total 75 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stat_type            222 non-null    object
#  1   attempt              0 non-null      float64
#  2   yards                0 non-null      float64
#  3   net_yards            0 non-null      float64
#  4   touchback            0 non-null      float64
#  5   onside_attempt       0 non-null      float64
#  6   onside_success       0 non-null      float64
#  7   squib_kick           0 non-null      float64
#  8   player.id            220 non-null    object
#  9   player.name          220 non-null    object
#  10  player.jersey        220 non-null    object
#  11  player.position      220 non-null    object
#  12  player.sr_id         220 non-null    object
#  13  team.id              222 non-null    object
#  14  team.name            222 non-null    object
#  15  team.market          222 non-null    object
#  16  team.alias           222 non-null    object
#  17  team.sr_id           222 non-null    object
#  18  category             161 non-null    object
#  19  play_id              222 non-null    object
#  20  complete             0 non-null      float64
#  21  att_yards            0 non-null      float64
#  22  firstdown            0 non-null      float64
#  23  inside_20            0 non-null      float64
#  24  goaltogo             0 non-null      float64
#  25  blitz                222 non-null    float64
#  26  hurry                222 non-null    float64
#  27  knockdown            222 non-null    float64
#  28  pocket_time          0 non-null      float64
#  29  on_target_throw      0 non-null      float64
#  30  batted_pass          222 non-null    float64
#  31  target               0 non-null      float64
#  32  reception            0 non-null      float64
#  33  yards_after_catch    0 non-null      float64
#  34  dropped              0 non-null      float64
#  35  catchable            0 non-null      float64
#  36  tackle               106 non-null    float64
#  37  missed_tackles       208 non-null    float64
#  38  def_target           222 non-null    float64
#  39  def_comp             222 non-null    float64
#  40  yards_after_contact  0 non-null      float64
#  41  broken_tackles       0 non-null      float64
#  42  kneel_down           0 non-null      float64
#  43  scramble             0 non-null      float64
#  44  ast_tackle           55 non-null     float64
#  45  qb_hit               14 non-null     float64
#  46  tlost                11 non-null     float64
#  47  penalty              0 non-null      float64
#  48  down                 0 non-null      float64
#  49  touchdown            0 non-null      float64
#  50  made                 0 non-null      float64
#  51  return               0 non-null      float64
#  52  incompletion_type    0 non-null      object
#  53  pass_defended        5 non-null      float64
#  54  hang_time            0 non-null      float64
#  55  out_of_bounds        0 non-null      float64
#  56  tlost_yards          12 non-null     float64
#  57  missed               0 non-null      float64
#  58  endzone              0 non-null      float64
#  59  nullified            6 non-null      object
#  60  ast_tlost            3 non-null      float64
#  61  sack                 4 non-null      float64
#  62  sack_yards           4 non-null      float64
#  63  fumble               0 non-null      float64
#  64  forced               0 non-null      float64
#  65  own_rec              0 non-null      float64
#  66  own_rec_yards        0 non-null      float64
#  67  play_category        0 non-null      object
#  68  forced_fumble        4 non-null      float64
#  69  opp_rec              0 non-null      float64
#  70  opp_rec_yards        0 non-null      float64
#  71  lost                 0 non-null      float64
#  72  interception         1 non-null      float64
#  73  int_yards            1 non-null      float64
#  74  faircatch            0 non-null      float64
# dtypes: float64(59), object(16)
# memory usage: 131.8+ KB

# %%
rel_cols = ['player.name', 'player.position', 'missed_tackles', 'def_target', 'def_comp', 'team.alias', 'play_id', 'missed_tackles']

# %%
def_stats_df = def_stats_df[(rel_cols)]

# %%
def_stats_df = def_stats_df[def_stats_df['def_target'] == 1]
# Out:
#             player.name player.position  missed_tackles  def_target  def_comp  \
# 2          Cole Holcomb              LB             0.0         1.0       1.0
# 2           Kamren Curl             SAF             0.0         1.0       1.0
# 2   William Jackson III              CB             0.0         1.0       1.0
# 3          Bobby McCain              CB             0.0         1.0       1.0
# 2         Casey Toohill              DE             0.0         1.0       1.0
# ..                  ...             ...             ...         ...       ...
# 2          Torry McTyer              CB             0.0         1.0       1.0
# 2     Benjamin St-Juste              DB             0.0         1.0       1.0
# 2     Benjamin St-Juste              DB             0.0         1.0       1.0
# 3   William Jackson III              CB             0.0         1.0       1.0
# 3   William Jackson III              CB             0.0         1.0       1.0
#
#    team.alias                               play_id  missed_tackles
# 2         WAS  b5a89790-13eb-11ec-96fd-fd610003fee8             0.0
# 2         WAS  d6c91f30-13eb-11ec-96fd-fd610003fee8             0.0
# 2         WAS  fdc12a60-13eb-11ec-96fd-fd610003fee8             0.0
# 3         WAS  27e59650-13ec-11ec-96fd-fd610003fee8             0.0
# 2         WAS  54c3f220-13ec-11ec-96fd-fd610003fee8             0.0
# ..        ...                                   ...             ...
# 2         WAS  b19f4ce0-1402-11ec-b7b0-4158b665dea8             0.0
# 2         WAS  f3dd00c0-1402-11ec-b7b0-4158b665dea8             0.0
# 2         WAS  f3dd00c0-1402-11ec-b7b0-4158b665dea8             0.0
# 3         WAS  9db07f50-1403-11ec-b7b0-4158b665dea8             0.0
# 3         WAS  9db07f50-1403-11ec-b7b0-4158b665dea8             0.0
#
# [73 rows x 8 columns]
